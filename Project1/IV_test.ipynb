# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import linearmodels.iv.model as lm
from scipy import stats
from itertools import combinations

# %%
def firstStageRegress(variables, endo):
    """First Stage Regression"""
    
    X_stage1 = sm.add_constant(df[variables])
    y_stage1 = df[endo]

    # Fit the regression to find the predicted values
    results_stage1 = sm.OLS(y_stage1, X_stage1).fit()
    predictor = results_stage1.predict(X_stage1)

    return results_stage1, predictor 

def secondStageRegress(variables, predict):  
    """Second Stage Regression"""
    
    X_stage2 = sm.add_constant(df[variables])
    y_stage2 = df[predict]  

    # Fit the regression model
    results_stage2 = sm.OLS(y_stage2, X_stage2).fit()
    
    return results_stage2

# %%
# Read dataset
df = pd.read_csv("Data-GP1-1(updated).csv")
df
# Out:
#      Mon  Tue  Wed  Thu  Date  Month  Year  Stormy  Mixed         p         q  \
# 0      1    0    0    0     2     12    91       1      0 -0.430783  8.994421
# 1      0    1    0    0     3     12    91       1      0  0.000000  7.707063
# 2      0    0    1    0     4     12    91       0      1  0.072321  8.350194
# 3      0    0    0    1     5     12    91       1      0  0.247139  8.656955
# 4      0    0    0    0     6     12    91       1      0  0.664327  7.844241
# ..   ...  ...  ...  ...   ...    ...   ...     ...    ...       ...       ...
# 106    1    0    0    0     4      5    92       0      0 -0.798508  8.610683
# 107    0    1    0    0     5      5    92       0      1 -0.087011  7.162397
# 108    0    0    1    0     6      5    92       0      1  0.184922  7.362010
# 109    0    0    0    1     7      5    92       0      1  0.223143  8.764053
# 110    0    0    0    0     8      5    92       0      1  0.561118  8.328451
#
#      Rainy  Cold      Wind
# 0        1     0  2.995732
# 1        0     0  2.995732
# 2        1     1  2.813411
# 3        0     1  3.036554
# 4        0     1  3.036554
# ..     ...   ...       ...
# 106      0     0  2.862201
# 107      0     0  2.908721
# 108      0     0  2.862201
# 109      0     0  2.813411
# 110      0     0  2.862201
#
# [111 rows x 14 columns]

# %%
# Generate all possible combinations of variables

combinations_list = []
variables = [col for col in df.columns if col not in ["q", "p"]] # Retrieving only the columns of interest

# Permutate and append combinations into a list
for r in range(1, len(variables) + 1):
    combinations_list.extend(combinations(variables, r))

# Print total number of combinations made
print(len(combinations_list))
# Out:
# 4095

# %%
# Weak Instrument Test, where significance level is deemed at 0.05%

sign_IVs = [] # IVs 
sign_phat = []
sign_result = []

for combination in combinations_list:
    # Setting IV Variables
    IV = list(combination)
    
    # Setting Exogenous Variable
    Exo = ["Mon","Tue","Wed","Thu"]
    
    # First Stage Regression
    result, p_hat = firstStageRegress(IV + Exo, "p")
    
    # Check that:
    # - the F Statistics p value is significant
    # - the IV variables are not present in the Exogenous Variables
    # - there are more than one IV variable
    if result.f_pvalue < 0.05 and all(iv not in Exo for iv in IV) and len(IV) != 1:  # Check if all p-values are less than 0.05
        # Append the corresponding IV variable into a list if true
        sign_IVs.append(IV)
        # Append the corresponding estimated coefficient into a list if true
        sign_phat.append(p_hat)
        # Append the corresponding regression result into a list if true
        sign_result.append(result)

# For combinations that fulfilled the conditionals, print out their IVs and corresponding F-statistics p value 
for idx, IV in enumerate(sign_IVs):
    print(f"{idx + 1}. IV:{IV}, Prob (F-stat):{sign_result[idx].f_pvalue}")
# Out:
# 1. IV:['Date', 'Stormy'], Prob (F-stat):0.0007685111179881521
# 2. IV:['Date', 'Cold'], Prob (F-stat):0.031971181025790954
# 3. IV:['Date', 'Wind'], Prob (F-stat):0.00020143786735149507
# 4. IV:['Month', 'Year'], Prob (F-stat):0.044780095341582775
# 5. IV:['Month', 'Stormy'], Prob (F-stat):0.0005497216954061974
# 6. IV:['Month', 'Wind'], Prob (F-stat):0.00015725489861969494
# 7. IV:['Year', 'Stormy'], Prob (F-stat):0.0002769901540010904
# 8. IV:['Year', 'Cold'], Prob (F-stat):0.04228873264902102
# 9. IV:['Year', 'Wind'], Prob (F-stat):8.98728923144987e-05
# 10. IV:['Stormy', 'Mixed'], Prob (F-stat):4.34850312546488e-05
# 11. IV:['Stormy', 'Rainy'], Prob (F-stat):0.0019177587524664896
# 12. IV:['Stormy', 'Cold'], Prob (F-stat):0.0011745959177015097
# 13. IV:['Stormy', 'Wind'], Prob (F-stat):0.0002272844034769734
# 14. IV:['Mixed', 'Wind'], Prob (F-stat):0.00036753279579365537
# 15. IV:['Rainy', 'Wind'], Prob (F-stat):0.0005174663785250746
# 16. IV:['Cold', 'Wind'], Prob (F-stat):0.00042319842910023403
# 17. IV:['Date', 'Month', 'Year'], Prob (F-stat):0.00873573439664947
# 18. IV:['Date', 'Month', 'Stormy'], Prob (F-stat):0.0005423884260694911
# 19. IV:['Date', 'Month', 'Cold'], Prob (F-stat):0.020718635703177068
# 20. IV:['Date', 'Month', 'Wind'], Prob (F-stat):0.0001601976813564218
# 21. IV:['Date', 'Year', 'Stormy'], Prob (F-stat):0.0002354249953374272
# 22. IV:['Date', 'Year', 'Cold'], Prob (F-stat):0.00882086857567084
# 23. IV:['Date', 'Year', 'Wind'], Prob (F-stat):7.881027999543141e-05
# 24. IV:['Date', 'Stormy', 'Mixed'], Prob (F-stat):6.75421071176912e-05
# 25. IV:['Date', 'Stormy', 'Rainy'], Prob (F-stat):0.0017231310275420797
# 26. IV:['Date', 'Stormy', 'Cold'], Prob (F-stat):0.0007082436417419213
# 27. IV:['Date', 'Stormy', 'Wind'], Prob (F-stat):0.0002324004879189872
# 28. IV:['Date', 'Mixed', 'Cold'], Prob (F-stat):0.045477893794319615
# 29. IV:['Date', 'Mixed', 'Wind'], Prob (F-stat):0.0003773259449501749
# 30. IV:['Date', 'Rainy', 'Wind'], Prob (F-stat):0.00048178693740958306
# 31. IV:['Date', 'Cold', 'Wind'], Prob (F-stat):0.0002959215770019125
# 32. IV:['Month', 'Year', 'Stormy'], Prob (F-stat):0.0003779418989640034
# 33. IV:['Month', 'Year', 'Cold'], Prob (F-stat):0.03344826813147369
# 34. IV:['Month', 'Year', 'Wind'], Prob (F-stat):0.0001523466897142688
# 35. IV:['Month', 'Stormy', 'Mixed'], Prob (F-stat):2.923399931853342e-05
# 36. IV:['Month', 'Stormy', 'Rainy'], Prob (F-stat):0.0012300389612373555
# 37. IV:['Month', 'Stormy', 'Cold'], Prob (F-stat):0.0007809921847120691
# 38. IV:['Month', 'Stormy', 'Wind'], Prob (F-stat):0.00016751374606675587
# 39. IV:['Month', 'Mixed', 'Wind'], Prob (F-stat):0.0002673127556289193
# 40. IV:['Month', 'Rainy', 'Wind'], Prob (F-stat):0.0003761679237628031
# 41. IV:['Month', 'Cold', 'Wind'], Prob (F-stat):0.00031237917843344114
# 42. IV:['Year', 'Stormy', 'Mixed'], Prob (F-stat):1.784364492194776e-05
# 43. IV:['Year', 'Stormy', 'Rainy'], Prob (F-stat):0.0006286719035776159
# 44. IV:['Year', 'Stormy', 'Cold'], Prob (F-stat):0.00047661917493885194
# 45. IV:['Year', 'Stormy', 'Wind'], Prob (F-stat):0.00010293038836116398
# 46. IV:['Year', 'Mixed', 'Wind'], Prob (F-stat):0.00015567303264319988
# 47. IV:['Year', 'Rainy', 'Wind'], Prob (F-stat):0.00021719641232061508
# 48. IV:['Year', 'Cold', 'Wind'], Prob (F-stat):0.00019988616372836212
# 49. IV:['Stormy', 'Mixed', 'Rainy'], Prob (F-stat):0.00011127410195252205
# 50. IV:['Stormy', 'Mixed', 'Cold'], Prob (F-stat):7.948800276007862e-05
# 51. IV:['Stormy', 'Mixed', 'Wind'], Prob (F-stat):7.27935245244715e-05
# 52. IV:['Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.002541915515548144
# 53. IV:['Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.0005369114821134364
# 54. IV:['Stormy', 'Cold', 'Wind'], Prob (F-stat):0.00047466065434936296
# 55. IV:['Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0008551629525235174
# 56. IV:['Mixed', 'Cold', 'Wind'], Prob (F-stat):0.0006680254066632037
# 57. IV:['Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0009730797708021278
# 58. IV:['Date', 'Month', 'Year', 'Stormy'], Prob (F-stat):0.00019814658399372072
# 59. IV:['Date', 'Month', 'Year', 'Mixed'], Prob (F-stat):0.014831180485296904
# 60. IV:['Date', 'Month', 'Year', 'Rainy'], Prob (F-stat):0.01630862344155284
# 61. IV:['Date', 'Month', 'Year', 'Cold'], Prob (F-stat):0.004676728164455385
# 62. IV:['Date', 'Month', 'Year', 'Wind'], Prob (F-stat):8.700553522026361e-05
# 63. IV:['Date', 'Month', 'Stormy', 'Mixed'], Prob (F-stat):4.6517398479159556e-05
# 64. IV:['Date', 'Month', 'Stormy', 'Rainy'], Prob (F-stat):0.0011792374170216569
# 65. IV:['Date', 'Month', 'Stormy', 'Cold'], Prob (F-stat):0.0005090635323631025
# 66. IV:['Date', 'Month', 'Stormy', 'Wind'], Prob (F-stat):0.00017814509679818142
# 67. IV:['Date', 'Month', 'Mixed', 'Cold'], Prob (F-stat):0.029115310395819605
# 68. IV:['Date', 'Month', 'Mixed', 'Wind'], Prob (F-stat):0.00028608746454807934
# 69. IV:['Date', 'Month', 'Rainy', 'Cold'], Prob (F-stat):0.03636626970715456
# 70. IV:['Date', 'Month', 'Rainy', 'Wind'], Prob (F-stat):0.00036955715291835654
# 71. IV:['Date', 'Month', 'Cold', 'Wind'], Prob (F-stat):0.00023176690981562884
# 72. IV:['Date', 'Year', 'Stormy', 'Mixed'], Prob (F-stat):2.5159293832762674e-05
# 73. IV:['Date', 'Year', 'Stormy', 'Rainy'], Prob (F-stat):0.0005265164244800287
# 74. IV:['Date', 'Year', 'Stormy', 'Cold'], Prob (F-stat):0.0002771088150340274
# 75. IV:['Date', 'Year', 'Stormy', 'Wind'], Prob (F-stat):9.483273392636786e-05
# 76. IV:['Date', 'Year', 'Mixed', 'Cold'], Prob (F-stat):0.013148398160374391
# 77. IV:['Date', 'Year', 'Mixed', 'Wind'], Prob (F-stat):0.00014519810153954058
# 78. IV:['Date', 'Year', 'Rainy', 'Cold'], Prob (F-stat):0.016466870331053908
# 79. IV:['Date', 'Year', 'Rainy', 'Wind'], Prob (F-stat):0.00018606905276549377
# 80. IV:['Date', 'Year', 'Cold', 'Wind'], Prob (F-stat):0.00013277606226457807
# 81. IV:['Date', 'Stormy', 'Mixed', 'Rainy'], Prob (F-stat):0.00016138030802535002
# 82. IV:['Date', 'Stormy', 'Mixed', 'Cold'], Prob (F-stat):8.97255874058485e-05
# 83. IV:['Date', 'Stormy', 'Mixed', 'Wind'], Prob (F-stat):0.00010312170010810852
# 84. IV:['Date', 'Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.0015233461140284072
# 85. IV:['Date', 'Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.0005280355720466014
# 86. IV:['Date', 'Stormy', 'Cold', 'Wind'], Prob (F-stat):0.00036758855201524674
# 87. IV:['Date', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0008352019835351963
# 88. IV:['Date', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.0004969877503203117
# 89. IV:['Date', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0006651661180912457
# 90. IV:['Month', 'Year', 'Stormy', 'Mixed'], Prob (F-stat):3.530445733734623e-05
# 91. IV:['Month', 'Year', 'Stormy', 'Rainy'], Prob (F-stat):0.0007878948350733327
# 92. IV:['Month', 'Year', 'Stormy', 'Cold'], Prob (F-stat):0.000752451986826788
# 93. IV:['Month', 'Year', 'Stormy', 'Wind'], Prob (F-stat):0.00018221689968322014
# 94. IV:['Month', 'Year', 'Mixed', 'Cold'], Prob (F-stat):0.04345357595255041
# 95. IV:['Month', 'Year', 'Mixed', 'Wind'], Prob (F-stat):0.00025055626010041823
# 96. IV:['Month', 'Year', 'Rainy', 'Wind'], Prob (F-stat):0.0003371718936684102
# 97. IV:['Month', 'Year', 'Cold', 'Wind'], Prob (F-stat):0.000345470069219892
# 98. IV:['Month', 'Stormy', 'Mixed', 'Rainy'], Prob (F-stat):7.211996479944935e-05
# 99. IV:['Month', 'Stormy', 'Mixed', 'Cold'], Prob (F-stat):5.252088663153858e-05
# 100. IV:['Month', 'Stormy', 'Mixed', 'Wind'], Prob (F-stat):4.9991486389899544e-05
# 101. IV:['Month', 'Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.0016177287145838402
# 102. IV:['Month', 'Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.00037642646858748914
# 103. IV:['Month', 'Stormy', 'Cold', 'Wind'], Prob (F-stat):0.00033992533412741176
# 104. IV:['Month', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0006012934239275447
# 105. IV:['Month', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.0004731138181481547
# 106. IV:['Month', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0006863782855303595
# 107. IV:['Year', 'Stormy', 'Mixed', 'Rainy'], Prob (F-stat):4.4412341478270344e-05
# 108. IV:['Year', 'Stormy', 'Mixed', 'Cold'], Prob (F-stat):3.6985381470332454e-05
# 109. IV:['Year', 'Stormy', 'Mixed', 'Wind'], Prob (F-stat):3.2807602038137834e-05
# 110. IV:['Year', 'Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.0009940342276523908
# 111. IV:['Year', 'Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.00023194279681154552
# 112. IV:['Year', 'Stormy', 'Cold', 'Wind'], Prob (F-stat):0.0002279103194117534
# 113. IV:['Year', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0003553888738030948
# 114. IV:['Year', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.0003113172930042008
# 115. IV:['Year', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.00044232524437486266
# 116. IV:['Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.00018904126417687228
# 117. IV:['Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.00017392639798100983
# 118. IV:['Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00014455755653676176
# 119. IV:['Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0010305031910222235
# 120. IV:['Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.001443495290762559
# 121. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed'], Prob (F-stat):3.6522279522609466e-05
# 122. IV:['Date', 'Month', 'Year', 'Stormy', 'Rainy'], Prob (F-stat):0.00042144145653286896
# 123. IV:['Date', 'Month', 'Year', 'Stormy', 'Cold'], Prob (F-stat):0.0003263816698138788
# 124. IV:['Date', 'Month', 'Year', 'Stormy', 'Wind'], Prob (F-stat):0.00011635664447309517
# 125. IV:['Date', 'Month', 'Year', 'Mixed', 'Rainy'], Prob (F-stat):0.02594973340976958
# 126. IV:['Date', 'Month', 'Year', 'Mixed', 'Cold'], Prob (F-stat):0.007354392517124198
# 127. IV:['Date', 'Month', 'Year', 'Mixed', 'Wind'], Prob (F-stat):0.00015831880192435048
# 128. IV:['Date', 'Month', 'Year', 'Rainy', 'Cold'], Prob (F-stat):0.008734677701016423
# 129. IV:['Date', 'Month', 'Year', 'Rainy', 'Wind'], Prob (F-stat):0.00019390408817939153
# 130. IV:['Date', 'Month', 'Year', 'Cold', 'Wind'], Prob (F-stat):0.0001740564827007088
# 131. IV:['Date', 'Month', 'Stormy', 'Mixed', 'Rainy'], Prob (F-stat):0.00010884879028884978
# 132. IV:['Date', 'Month', 'Stormy', 'Mixed', 'Cold'], Prob (F-stat):6.242893270628743e-05
# 133. IV:['Date', 'Month', 'Stormy', 'Mixed', 'Wind'], Prob (F-stat):7.326557202581433e-05
# 134. IV:['Date', 'Month', 'Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.001060028970624755
# 135. IV:['Date', 'Month', 'Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.00039127727369732494
# 136. IV:['Date', 'Month', 'Stormy', 'Cold', 'Wind'], Prob (F-stat):0.0002791588191278607
# 137. IV:['Date', 'Month', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.04828291201964389
# 138. IV:['Date', 'Month', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0006209326686081811
# 139. IV:['Date', 'Month', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00037448116660180654
# 140. IV:['Date', 'Month', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0005041554972930642
# 141. IV:['Date', 'Year', 'Stormy', 'Mixed', 'Rainy'], Prob (F-stat):5.999157459133485e-05
# 142. IV:['Date', 'Year', 'Stormy', 'Mixed', 'Cold'], Prob (F-stat):3.9853929852416086e-05
# 143. IV:['Date', 'Year', 'Stormy', 'Mixed', 'Wind'], Prob (F-stat):4.2732640728624186e-05
# 144. IV:['Date', 'Year', 'Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.0005861049595872118
# 145. IV:['Date', 'Year', 'Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.00021147725494452676
# 146. IV:['Date', 'Year', 'Stormy', 'Cold', 'Wind'], Prob (F-stat):0.0001684533908140033
# 147. IV:['Date', 'Year', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.023188547417128162
# 148. IV:['Date', 'Year', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.00032349442738841813
# 149. IV:['Date', 'Year', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00022182992774740873
# 150. IV:['Date', 'Year', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0002932731503794247
# 151. IV:['Date', 'Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.00020460795441982127
# 152. IV:['Date', 'Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0002335883359062083
# 153. IV:['Date', 'Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00015965422167951138
# 154. IV:['Date', 'Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0007865531253827231
# 155. IV:['Date', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0010513538031518064
# 156. IV:['Month', 'Year', 'Stormy', 'Mixed', 'Rainy'], Prob (F-stat):8.134241009743821e-05
# 157. IV:['Month', 'Year', 'Stormy', 'Mixed', 'Cold'], Prob (F-stat):7.651661414572275e-05
# 158. IV:['Month', 'Year', 'Stormy', 'Mixed', 'Wind'], Prob (F-stat):6.469429808943126e-05
# 159. IV:['Month', 'Year', 'Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.001458295062919631
# 160. IV:['Month', 'Year', 'Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.0003789341494416844
# 161. IV:['Month', 'Year', 'Stormy', 'Cold', 'Wind'], Prob (F-stat):0.00040017874495118494
# 162. IV:['Month', 'Year', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0005322003846013927
# 163. IV:['Month', 'Year', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.000525308973106403
# 164. IV:['Month', 'Year', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0007098494743686681
# 165. IV:['Month', 'Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.00012084240682734709
# 166. IV:['Month', 'Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.00011575457948785901
# 167. IV:['Month', 'Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):9.71728093872914e-05
# 168. IV:['Month', 'Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0007076110264355785
# 169. IV:['Month', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0009940130718447554
# 170. IV:['Year', 'Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):8.540712213774448e-05
# 171. IV:['Year', 'Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):7.637437135954896e-05
# 172. IV:['Year', 'Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):7.039438276910304e-05
# 173. IV:['Year', 'Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0004755197115420964
# 174. IV:['Year', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0006604618922312159
# 175. IV:['Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.00032253542594475
# 176. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed', 'Rainy'], Prob (F-stat):8.22707699796987e-05
# 177. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed', 'Cold'], Prob (F-stat):6.76392989757104e-05
# 178. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed', 'Wind'], Prob (F-stat):6.422931519207366e-05
# 179. IV:['Date', 'Month', 'Year', 'Stormy', 'Rainy', 'Cold'], Prob (F-stat):0.0006547678599167201
# 180. IV:['Date', 'Month', 'Year', 'Stormy', 'Rainy', 'Wind'], Prob (F-stat):0.0002451430373564711
# 181. IV:['Date', 'Month', 'Year', 'Stormy', 'Cold', 'Wind'], Prob (F-stat):0.0002323283905610903
# 182. IV:['Date', 'Month', 'Year', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.013083953138520432
# 183. IV:['Date', 'Month', 'Year', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.0003368892577307296
# 184. IV:['Date', 'Month', 'Year', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00029152478651066143
# 185. IV:['Date', 'Month', 'Year', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.00036395419297599255
# 186. IV:['Date', 'Month', 'Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.0001392310165854954
# 187. IV:['Date', 'Month', 'Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.00016283835576576012
# 188. IV:['Date', 'Month', 'Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00011305017645028995
# 189. IV:['Date', 'Month', 'Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0005789702111732858
# 190. IV:['Date', 'Month', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0007772133896893483
# 191. IV:['Date', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):8.982820399933864e-05
# 192. IV:['Date', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):9.639424726531533e-05
# 193. IV:['Date', 'Year', 'Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):7.458403452387035e-05
# 194. IV:['Date', 'Year', 'Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.00035300237655063854
# 195. IV:['Date', 'Year', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.00046841769106508276
# 196. IV:['Date', 'Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0003444848444865965
# 197. IV:['Month', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.00016507343161706512
# 198. IV:['Month', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.00014050882090740972
# 199. IV:['Month', 'Year', 'Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00013958257149431616
# 200. IV:['Month', 'Year', 'Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0007802395786998337
# 201. IV:['Month', 'Year', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0010455067546271282
# 202. IV:['Month', 'Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0002109348754212088
# 203. IV:['Year', 'Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0001532264278672788
# 204. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Cold'], Prob (F-stat):0.0001442343415719106
# 205. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Wind'], Prob (F-stat):0.00013740407400814875
# 206. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed', 'Cold', 'Wind'], Prob (F-stat):0.00012348142353803471
# 207. IV:['Date', 'Month', 'Year', 'Stormy', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.00046203273721968566
# 208. IV:['Date', 'Month', 'Year', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0005873096978590603
# 209. IV:['Date', 'Month', 'Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0002394215020356898
# 210. IV:['Date', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0001594488773497068
# 211. IV:['Month', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0002857815619287057
# 212. IV:['Date', 'Month', 'Year', 'Stormy', 'Mixed', 'Rainy', 'Cold', 'Wind'], Prob (F-stat):0.0002509742724971598

# %%
# Wu-Hausman Test and Sargan Test, where significance level is deemed at 0.05%

sign_IVs_2 = []
feasible_combi = []

# Iterate through the combinations of IVs identified from Weak Instrument Test
for idx, iv_combination in enumerate(sign_IVs):
    # Perform 2 Step Least Square Regression
    mlr2 = lm.IV2SLS(dependent=df[["q"]], 
                     exog=df[["Mon","Tue","Wed","Thu"]], 
                     endog=df[["p"]], 
                     instruments=df[list(iv_combination)]).fit(cov_type="homoskedastic", debiased=True)
    
    # Check that:
    # - p-value of Wu-Hausman test is significant
    # - p-value of Sargan test is insignificant
    if mlr2.wu_hausman().pval < 0.05 and mlr2.sargan.pval > 0.05:
        # Append the corresponding IV variable into a list if true
        sign_IVs_2.append(iv_combination)

# For combinations that fulfilled the conditionals, append them into a list
for idx, combination in enumerate(sign_IVs_2):
    IV = combination
    Exo = ["Mon","Tue","Wed","Thu"]
    
    # Perform First Stage Regression
    result, p_hat = firstStageRegress(IV + Exo, "p")
    
    feasible_combi.append({
        "iv": IV,
        "result": result,
        "p_hat": p_hat
    })
    
# Print out the combinations in ascending order based on the p-values of the F-statistics test
sorted_combi = sorted(feasible_combi, key=lambda x: x['result'].f_pvalue)    
for idx, combination in enumerate(sorted_combi):
    print(f"{idx+1}. IVs: {combination['iv']}, Prob (F-Stat):{combination['result'].f_pvalue}")
# Out:
# 1. IVs: ['Stormy', 'Mixed'], Prob (F-Stat):4.34850312546488e-05
# 2. IVs: ['Stormy', 'Mixed', 'Cold'], Prob (F-Stat):7.948800276007862e-05
# 3. IVs: ['Month', 'Mixed', 'Wind'], Prob (F-Stat):0.0002673127556289193
# 4. IVs: ['Mixed', 'Wind'], Prob (F-Stat):0.00036753279579365537
# 5. IVs: ['Month', 'Rainy', 'Wind'], Prob (F-Stat):0.0003761679237628031
# 6. IVs: ['Rainy', 'Wind'], Prob (F-Stat):0.0005174663785250746
# 7. IVs: ['Month', 'Mixed', 'Rainy', 'Wind'], Prob (F-Stat):0.0006012934239275447
# 8. IVs: ['Mixed', 'Rainy', 'Wind'], Prob (F-Stat):0.0008551629525235174
# 9. IVs: ['Stormy', 'Cold'], Prob (F-Stat):0.0011745959177015097

# %% [markdown]
# Since it doesn't make sense for "Cold" and "Month" to be IVs, we leave out combinations that consist these variables, allowing us to settle on 4 combinations to test.
