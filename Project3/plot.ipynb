# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

# %%
ucb_df = pd.read_csv("./csv_data/UCB1_v2.csv")
uni_df = pd.read_csv("./csv_data/uniform_explor.csv")
greedy_df = pd.read_csv("./csv_data/epsilon_greedy_results.csv")
adapt_exp_df = pd.read_csv("./csv_data/adapt_exp.csv")
adapt_overt_df = pd.read_csv("./csv_data/adapt_overt.csv")

# %% [markdown]
# ## All 1000 rounds

# %%
plt.plot(uni_df["round"], uni_df["regret"], label="Uniform")
plt.plot(ucb_df["Unnamed: 0"], ucb_df["regret"], label="UCB")
plt.plot(greedy_df["Pull_Number"], greedy_df["Regret"], label="Greedy")
plt.plot(adapt_exp_df["round"], adapt_exp_df["regret"], label="Adapt(exp)")
plt.plot(adapt_overt_df["round"], adapt_overt_df["regret"], label="Adapt(1/t)")

plt.xlabel("No. of Rounds")
plt.ylabel("Total Regret")

plt.legend()

plt.show()

# %%
plt.plot(uni_df["round"], uni_df["cum_reward"], label="Uniform")
plt.plot(ucb_df["Unnamed: 0"], ucb_df["reward"], label="UCB")
plt.plot(greedy_df["Pull_Number"], greedy_df["Cumulative_Reward"], label="Greedy")
plt.plot(adapt_exp_df["round"], adapt_exp_df["cum_reward"], label="Adapt(exp)")
plt.plot(adapt_overt_df["round"], adapt_overt_df["cum_reward"], label="Adapt(1/t)")

plt.xlabel("No. of Rounds")
plt.ylabel("Total Reward")

plt.legend()

plt.show()

# %% [markdown]
# ## First 100 rounds

# %%
unit_num = 100

plt.plot(uni_df["round"][:unit_num], uni_df["regret"][:unit_num], label='Uni')
plt.plot(ucb_df["Unnamed: 0"][:unit_num], ucb_df["regret"][:unit_num], label='UCB')
plt.plot(greedy_df["Pull_Number"][:unit_num], greedy_df["Regret"][:unit_num], label='Greedy')
plt.plot(adapt_exp_df["round"][:unit_num], adapt_exp_df["regret"][:unit_num], label='Adapt(exp)')
plt.plot(adapt_overt_df["round"][:unit_num], adapt_overt_df["regret"][:unit_num], label='Adapt(1/t)')

plt.xlabel("No. of Rounds")
plt.ylabel("Total Regret")

# Add legend
plt.legend()

plt.show()

# %%
unit_num = 100

plt.plot(uni_df["round"][:unit_num], uni_df["cum_reward"][:unit_num], label="Uniform")
plt.plot(ucb_df["Unnamed: 0"][:unit_num], ucb_df["reward"][:unit_num], label="UCB")
plt.plot(greedy_df["Pull_Number"][:unit_num], greedy_df["Cumulative_Reward"][:unit_num], label="Greedy")
plt.plot(adapt_exp_df["round"][:unit_num], adapt_exp_df["cum_reward"][:unit_num], label="Adapt(exp)")
plt.plot(adapt_overt_df["round"][:unit_num], adapt_overt_df["cum_reward"][:unit_num], label="Adapt(1/t)")

plt.xlabel("No. of Rounds")
plt.ylabel("Total Reward")

plt.legend()

plt.show()

# %% [markdown]
# ## Best arms identified
#
# - **Uniform Exploration**: 21
# - **Upper Confidence Bound**: 21
# - **Epsilon-Greedy**: 21
# - **Adaptive Epsilon-Greedy (exp)**: 21
# - **Adaptive Epsilon-Greedy (1/t)**: 13
