# %% [markdown]
# ## Uniform Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#################################################################################################

def uniform_explor(user_group, secret_key, N, tot_rounds):
    
    # Initialize the result dict with arms and statistics
    result = {idx: {
                    "Arm": idx,
                    "Output_Arm": 0,
                    "N_List": [], # Rewards gotten during Exploration
                    "Reward_List": [], # Rewards obtained throughout rounds
                    "Round_List": [], # Rounds which the arm is pulled
                    } for idx in range(TOT_MACHINE)
             }
    
    # Calculates the number of rounds left for Exploitation
    cut_off = tot_rounds - (TOT_MACHINE*N)
    
    # If number of rounds for Exploitation <= 0, do not pull
    if cut_off <= 0:
        print("Insufficient Total Rounds")
    
    else:
        arm = 0
        
        for num_round in range(tot_rounds):
            
            # If iterating through Exploration rounds
            if (num_round + 1) <= (TOT_MACHINE*N):
                # Simulate pulling an arm and getting an output
                # output = test_pull(user_group,secret_key,arm)
                output = pull(user_group,secret_key,arm)
                
                print(f"#{num_round}: {output}")
                
                result[arm]["Output_Arm"] = output["Arm"]
                result[arm]["Reward_List"].append(output["Reward"])
                result[arm]["Round_List"].append(num_round)
                
                result[arm]["N_List"].append(output["Reward"])
                
                # Iterate through the machines 
                if arm == (TOT_MACHINE - 1):
                    arm = 0
                else:
                    arm = arm + 1                

            # If Exploration rounds are over, enter Exploitation rounds
            else:              
                # Identify the arm with the highest average Reward value across N_list
                arm = max(result, key=lambda k: sum(result[k]["N_List"]))
                
                # Simulate pulling an arm and getting an output
                # output = test_pull(user_group,secret_key,arm)
                output = pull(user_group,secret_key,arm)
                
                print(f"#{num_round}: {output}")
            
                result[arm]["Output_Arm"] = output["Arm"]
                result[arm]["Reward_List"].append(output["Reward"])
                result[arm]["Round_List"].append(num_round)
        
        list_result = [
            {
                **v, 
                "Total_Reward": sum(v["Reward_List"]),
                "Avg_N": sum(v["N_List"]) / len(v["N_List"]),
                "Avg_Reward": sum(v["Reward_List"]) / len(v["Reward_List"])
            } for v in result.values()
        ]
            
        return list_result

#################################################################################################

# %%
def regret(result, tot_round):
    best_result = max(result, key=lambda x:len(x["Reward_List"]))
    
    print(f"Best Arm Identified: {best_result}\n")
    
    x = [i for i in range(1, tot_round+1)]
    y = []
    
    best_mean = sum(best_result["Reward_List"])/len(best_result["Reward_List"])
    
    for num_round in range(1, tot_round+1):        
        indices = [idx for idx, round_num in enumerate(best_result["Round_List"]) if round_num <= num_round]
        tot_rewards = sum([best_result["Reward_List"][idx] for idx in indices])
        
        y.append((best_mean * num_round) - tot_rewards)

    # Graph Plot
    plt.plot(x,y)
    plt.xlabel("No. of Rounds")
    plt.ylabel("Total Regret")
    plt.show()
    
    return pd.DataFrame({"Round":x, "Regret": y})

# %%
from server_pull import pull

tot_rounds = 500
N_rounds = 10

# result = uniform_explor("test_user", "aaaaaaaa", N_rounds, tot_rounds)
result = uniform_explor('user40','XEq6wByD', N_rounds, tot_rounds)

print("\n##########################################################################################")
print("Total Runs")
print("##########################################################################################\n")
for elem in result:
    print(elem)

print("\n##########################################################################################")
print("Regret Plot")
print("##########################################################################################\n")
regret_df = regret(result, tot_rounds)

# Save regret dataframe as csv
regret_df.to_csv('uniform_explor.csv', index=False)
# Out:
# #0: {'Arm': '0', 'NetReward': 352727, 'Pull': 17207, 'Reward': 2}
# #1: {'Arm': '1', 'NetReward': 352743, 'Pull': 17208, 'Reward': 16}
# #2: {'Arm': '2', 'NetReward': 352757, 'Pull': 17209, 'Reward': 14}
# #3: {'Arm': '3', 'NetReward': 352784, 'Pull': 17210, 'Reward': 27}
# #4: {'Arm': '4', 'NetReward': 352796, 'Pull': 17211, 'Reward': 12}
# #5: {'Arm': '5', 'NetReward': 352818, 'Pull': 17212, 'Reward': 22}
# #6: {'Arm': '6', 'NetReward': 352831, 'Pull': 17213, 'Reward': 13}
# #7: {'Arm': '7', 'NetReward': 352854, 'Pull': 17214, 'Reward': 23}
# #8: {'Arm': '8', 'NetReward': 352869, 'Pull': 17215, 'Reward': 15}
# #9: {'Arm': '9', 'NetReward': 352884, 'Pull': 17216, 'Reward': 15}
# #10: {'Arm': '10', 'NetReward': 352909, 'Pull': 17217, 'Reward': 25}
# #11: {'Arm': '11', 'NetReward': 352915, 'Pull': 17218, 'Reward': 6}
# #12: {'Arm': '12', 'NetReward': 352923, 'Pull': 17219, 'Reward': 8}
# #13: {'Arm': '13', 'NetReward': 352944, 'Pull': 17220, 'Reward': 21}
# #14: {'Arm': '14', 'NetReward': 352953, 'Pull': 17221, 'Reward': 9}
# #15: {'Arm': '15', 'NetReward': 352976, 'Pull': 17222, 'Reward': 23}
# #16: {'Arm': '16', 'NetReward': 352995, 'Pull': 17223, 'Reward': 19}
# #17: {'Arm': '17', 'NetReward': 353003, 'Pull': 17224, 'Reward': 8}
# #18: {'Arm': '18', 'NetReward': 353017, 'Pull': 17225, 'Reward': 14}
# #19: {'Arm': '19', 'NetReward': 353024, 'Pull': 17226, 'Reward': 7}
# #20: {'Arm': '20', 'NetReward': 353048, 'Pull': 17227, 'Reward': 24}
# #21: {'Arm': '21', 'NetReward': 353073, 'Pull': 17228, 'Reward': 25}
# #22: {'Arm': '22', 'NetReward': 353084, 'Pull': 17229, 'Reward': 11}
# #23: {'Arm': '23', 'NetReward': 353105, 'Pull': 17230, 'Reward': 21}
# #24: {'Arm': '0', 'NetReward': 353110, 'Pull': 17231, 'Reward': 5}
# #25: {'Arm': '1', 'NetReward': 353126, 'Pull': 17232, 'Reward': 16}
# #26: {'Arm': '2', 'NetReward': 353151, 'Pull': 17233, 'Reward': 25}
# #27: {'Arm': '3', 'NetReward': 353165, 'Pull': 17234, 'Reward': 14}
# #28: {'Arm': '4', 'NetReward': 353176, 'Pull': 17235, 'Reward': 11}
# #29: {'Arm': '5', 'NetReward': 353201, 'Pull': 17236, 'Reward': 25}
# #30: {'Arm': '6', 'NetReward': 353214, 'Pull': 17237, 'Reward': 13}
# #31: {'Arm': '7', 'NetReward': 353230, 'Pull': 17238, 'Reward': 16}
# #32: {'Arm': '8', 'NetReward': 353251, 'Pull': 17239, 'Reward': 21}
# #33: {'Arm': '9', 'NetReward': 353266, 'Pull': 17240, 'Reward': 15}
# #34: {'Arm': '10', 'NetReward': 353286, 'Pull': 17241, 'Reward': 20}
# #35: {'Arm': '11', 'NetReward': 353296, 'Pull': 17242, 'Reward': 10}
# #36: {'Arm': '12', 'NetReward': 353303, 'Pull': 17243, 'Reward': 7}
# #37: {'Arm': '13', 'NetReward': 353334, 'Pull': 17244, 'Reward': 31}
# #38: {'Arm': '14', 'NetReward': 353341, 'Pull': 17245, 'Reward': 7}
# #39: {'Arm': '15', 'NetReward': 353358, 'Pull': 17246, 'Reward': 17}
# #40: {'Arm': '16', 'NetReward': 353373, 'Pull': 17247, 'Reward': 15}
# #41: {'Arm': '17', 'NetReward': 353384, 'Pull': 17248, 'Reward': 11}
# #42: {'Arm': '18', 'NetReward': 353399, 'Pull': 17249, 'Reward': 15}
# #43: {'Arm': '19', 'NetReward': 353407, 'Pull': 17250, 'Reward': 8}
# #44: {'Arm': '20', 'NetReward': 353431, 'Pull': 17251, 'Reward': 24}
# #45: {'Arm': '21', 'NetReward': 353449, 'Pull': 17252, 'Reward': 18}
# #46: {'Arm': '22', 'NetReward': 353459, 'Pull': 17253, 'Reward': 10}
# #47: {'Arm': '23', 'NetReward': 353472, 'Pull': 17254, 'Reward': 13}
# #48: {'Arm': '0', 'NetReward': 353480, 'Pull': 17255, 'Reward': 8}
# #49: {'Arm': '1', 'NetReward': 353495, 'Pull': 17256, 'Reward': 15}
# #50: {'Arm': '2', 'NetReward': 353521, 'Pull': 17257, 'Reward': 26}
# #51: {'Arm': '3', 'NetReward': 353544, 'Pull': 17258, 'Reward': 23}
# #52: {'Arm': '4', 'NetReward': 353566, 'Pull': 17259, 'Reward': 22}
# #53: {'Arm': '5', 'NetReward': 353588, 'Pull': 17260, 'Reward': 22}
# #54: {'Arm': '6', 'NetReward': 353600, 'Pull': 17261, 'Reward': 12}
# #55: {'Arm': '7', 'NetReward': 353615, 'Pull': 17262, 'Reward': 15}
# #56: {'Arm': '8', 'NetReward': 353619, 'Pull': 17263, 'Reward': 4}
# #57: {'Arm': '9', 'NetReward': 353639, 'Pull': 17264, 'Reward': 20}
# #58: {'Arm': '10', 'NetReward': 353663, 'Pull': 17265, 'Reward': 24}
# #59: {'Arm': '11', 'NetReward': 353686, 'Pull': 17266, 'Reward': 23}
# #60: {'Arm': '12', 'NetReward': 353690, 'Pull': 17267, 'Reward': 4}
# #61: {'Arm': '13', 'NetReward': 353712, 'Pull': 17268, 'Reward': 22}
# #62: {'Arm': '14', 'NetReward': 353724, 'Pull': 17269, 'Reward': 12}
# #63: {'Arm': '15', 'NetReward': 353742, 'Pull': 17270, 'Reward': 18}
# #64: {'Arm': '16', 'NetReward': 353756, 'Pull': 17271, 'Reward': 14}
# #65: {'Arm': '17', 'NetReward': 353766, 'Pull': 17272, 'Reward': 10}
# #66: {'Arm': '18', 'NetReward': 353778, 'Pull': 17273, 'Reward': 12}
# #67: {'Arm': '19', 'NetReward': 353782, 'Pull': 17274, 'Reward': 4}
# #68: {'Arm': '20', 'NetReward': 353798, 'Pull': 17275, 'Reward': 16}
# #69: {'Arm': '21', 'NetReward': 353828, 'Pull': 17276, 'Reward': 30}
# #70: {'Arm': '22', 'NetReward': 353838, 'Pull': 17277, 'Reward': 10}
# #71: {'Arm': '23', 'NetReward': 353852, 'Pull': 17278, 'Reward': 14}
# #72: {'Arm': '0', 'NetReward': 353861, 'Pull': 17279, 'Reward': 9}
# #73: {'Arm': '1', 'NetReward': 353881, 'Pull': 17280, 'Reward': 20}
# #74: {'Arm': '2', 'NetReward': 353899, 'Pull': 17281, 'Reward': 18}
# #75: {'Arm': '3', 'NetReward': 353912, 'Pull': 17282, 'Reward': 13}
# #76: {'Arm': '4', 'NetReward': 353929, 'Pull': 17283, 'Reward': 17}
# #77: {'Arm': '5', 'NetReward': 353943, 'Pull': 17284, 'Reward': 14}
# #78: {'Arm': '6', 'NetReward': 353961, 'Pull': 17285, 'Reward': 18}
# #79: {'Arm': '7', 'NetReward': 353981, 'Pull': 17286, 'Reward': 20}
# #80: {'Arm': '8', 'NetReward': 353995, 'Pull': 17287, 'Reward': 14}
# #81: {'Arm': '9', 'NetReward': 354012, 'Pull': 17288, 'Reward': 17}
# #82: {'Arm': '10', 'NetReward': 354026, 'Pull': 17289, 'Reward': 14}
# #83: {'Arm': '11', 'NetReward': 354038, 'Pull': 17290, 'Reward': 12}
# #84: {'Arm': '12', 'NetReward': 354045, 'Pull': 17291, 'Reward': 7}
# #85: {'Arm': '13', 'NetReward': 354072, 'Pull': 17292, 'Reward': 27}
# #86: {'Arm': '14', 'NetReward': 354074, 'Pull': 17293, 'Reward': 2}
# #87: {'Arm': '15', 'NetReward': 354094, 'Pull': 17294, 'Reward': 20}
# #88: {'Arm': '16', 'NetReward': 354109, 'Pull': 17295, 'Reward': 15}
# #89: {'Arm': '17', 'NetReward': 354118, 'Pull': 17296, 'Reward': 9}
# #90: {'Arm': '18', 'NetReward': 354136, 'Pull': 17297, 'Reward': 18}
# #91: {'Arm': '19', 'NetReward': 354143, 'Pull': 17298, 'Reward': 7}
# #92: {'Arm': '20', 'NetReward': 354166, 'Pull': 17299, 'Reward': 23}
# #93: {'Arm': '21', 'NetReward': 354194, 'Pull': 17300, 'Reward': 28}
# #94: {'Arm': '22', 'NetReward': 354199, 'Pull': 17301, 'Reward': 5}
# #95: {'Arm': '23', 'NetReward': 354215, 'Pull': 17302, 'Reward': 16}
# #96: {'Arm': '0', 'NetReward': 354220, 'Pull': 17303, 'Reward': 5}
# #97: {'Arm': '1', 'NetReward': 354236, 'Pull': 17304, 'Reward': 16}
# #98: {'Arm': '2', 'NetReward': 354258, 'Pull': 17305, 'Reward': 22}
# #99: {'Arm': '3', 'NetReward': 354273, 'Pull': 17306, 'Reward': 15}
# #100: {'Arm': '4', 'NetReward': 354297, 'Pull': 17307, 'Reward': 24}
# #101: {'Arm': '5', 'NetReward': 354314, 'Pull': 17308, 'Reward': 17}
# #102: {'Arm': '6', 'NetReward': 354326, 'Pull': 17309, 'Reward': 12}
# #103: {'Arm': '7', 'NetReward': 354344, 'Pull': 17310, 'Reward': 18}
# #104: {'Arm': '8', 'NetReward': 354354, 'Pull': 17311, 'Reward': 10}
# #105: {'Arm': '9', 'NetReward': 354373, 'Pull': 17312, 'Reward': 19}
# #106: {'Arm': '10', 'NetReward': 354392, 'Pull': 17313, 'Reward': 19}
# #107: {'Arm': '11', 'NetReward': 354403, 'Pull': 17314, 'Reward': 11}
# #108: {'Arm': '12', 'NetReward': 354408, 'Pull': 17315, 'Reward': 5}
# #109: {'Arm': '13', 'NetReward': 354421, 'Pull': 17316, 'Reward': 13}
# #110: {'Arm': '14', 'NetReward': 354424, 'Pull': 17317, 'Reward': 3}
# #111: {'Arm': '15', 'NetReward': 354449, 'Pull': 17318, 'Reward': 25}
# #112: {'Arm': '16', 'NetReward': 354457, 'Pull': 17319, 'Reward': 8}
# #113: {'Arm': '17', 'NetReward': 354472, 'Pull': 17320, 'Reward': 15}
# #114: {'Arm': '18', 'NetReward': 354482, 'Pull': 17321, 'Reward': 10}
# #115: {'Arm': '19', 'NetReward': 354488, 'Pull': 17322, 'Reward': 6}
# #116: {'Arm': '20', 'NetReward': 354510, 'Pull': 17323, 'Reward': 22}
# #117: {'Arm': '21', 'NetReward': 354535, 'Pull': 17324, 'Reward': 25}
# #118: {'Arm': '22', 'NetReward': 354543, 'Pull': 17325, 'Reward': 8}
# #119: {'Arm': '23', 'NetReward': 354553, 'Pull': 17326, 'Reward': 10}
# #120: {'Arm': '0', 'NetReward': 354556, 'Pull': 17327, 'Reward': 3}
# #121: {'Arm': '1', 'NetReward': 354569, 'Pull': 17328, 'Reward': 13}
# #122: {'Arm': '2', 'NetReward': 354582, 'Pull': 17329, 'Reward': 13}
# #123: {'Arm': '3', 'NetReward': 354593, 'Pull': 17330, 'Reward': 11}
# #124: {'Arm': '4', 'NetReward': 354606, 'Pull': 17331, 'Reward': 13}
# #125: {'Arm': '5', 'NetReward': 354632, 'Pull': 17332, 'Reward': 26}
# #126: {'Arm': '6', 'NetReward': 354652, 'Pull': 17333, 'Reward': 20}
# #127: {'Arm': '7', 'NetReward': 354667, 'Pull': 17334, 'Reward': 15}
# #128: {'Arm': '8', 'NetReward': 354677, 'Pull': 17335, 'Reward': 10}
# #129: {'Arm': '9', 'NetReward': 354692, 'Pull': 17336, 'Reward': 15}
# #130: {'Arm': '10', 'NetReward': 354712, 'Pull': 17337, 'Reward': 20}
# #131: {'Arm': '11', 'NetReward': 354727, 'Pull': 17338, 'Reward': 15}
# #132: {'Arm': '12', 'NetReward': 354736, 'Pull': 17339, 'Reward': 9}
# #133: {'Arm': '13', 'NetReward': 354758, 'Pull': 17340, 'Reward': 22}
# #134: {'Arm': '14', 'NetReward': 354765, 'Pull': 17341, 'Reward': 7}
# #135: {'Arm': '15', 'NetReward': 354788, 'Pull': 17342, 'Reward': 23}
# #136: {'Arm': '16', 'NetReward': 354799, 'Pull': 17343, 'Reward': 11}
# #137: {'Arm': '17', 'NetReward': 354804, 'Pull': 17344, 'Reward': 5}
# #138: {'Arm': '18', 'NetReward': 354814, 'Pull': 17345, 'Reward': 10}
# #139: {'Arm': '19', 'NetReward': 354822, 'Pull': 17346, 'Reward': 8}
# #140: {'Arm': '20', 'NetReward': 354834, 'Pull': 17347, 'Reward': 12}
# #141: {'Arm': '21', 'NetReward': 354853, 'Pull': 17348, 'Reward': 19}
# #142: {'Arm': '22', 'NetReward': 354858, 'Pull': 17349, 'Reward': 5}
# #143: {'Arm': '23', 'NetReward': 354875, 'Pull': 17350, 'Reward': 17}
# #144: {'Arm': '0', 'NetReward': 354883, 'Pull': 17351, 'Reward': 8}
# #145: {'Arm': '1', 'NetReward': 354895, 'Pull': 17352, 'Reward': 12}
# #146: {'Arm': '2', 'NetReward': 354928, 'Pull': 17353, 'Reward': 33}
# #147: {'Arm': '3', 'NetReward': 354944, 'Pull': 17354, 'Reward': 16}
# #148: {'Arm': '4', 'NetReward': 354961, 'Pull': 17355, 'Reward': 17}
# #149: {'Arm': '5', 'NetReward': 354980, 'Pull': 17356, 'Reward': 19}
# #150: {'Arm': '6', 'NetReward': 354991, 'Pull': 17357, 'Reward': 11}
# #151: {'Arm': '7', 'NetReward': 355013, 'Pull': 17358, 'Reward': 22}
# #152: {'Arm': '8', 'NetReward': 355033, 'Pull': 17359, 'Reward': 20}
# #153: {'Arm': '9', 'NetReward': 355054, 'Pull': 17360, 'Reward': 21}
# #154: {'Arm': '10', 'NetReward': 355073, 'Pull': 17361, 'Reward': 19}
# #155: {'Arm': '11', 'NetReward': 355081, 'Pull': 17362, 'Reward': 8}
# #156: {'Arm': '12', 'NetReward': 355087, 'Pull': 17363, 'Reward': 6}
# #157: {'Arm': '13', 'NetReward': 355114, 'Pull': 17364, 'Reward': 27}
# #158: {'Arm': '14', 'NetReward': 355117, 'Pull': 17365, 'Reward': 3}
# #159: {'Arm': '15', 'NetReward': 355133, 'Pull': 17366, 'Reward': 16}
# #160: {'Arm': '16', 'NetReward': 355150, 'Pull': 17367, 'Reward': 17}
# #161: {'Arm': '17', 'NetReward': 355161, 'Pull': 17368, 'Reward': 11}
# #162: {'Arm': '18', 'NetReward': 355172, 'Pull': 17369, 'Reward': 11}
# #163: {'Arm': '19', 'NetReward': 355180, 'Pull': 17370, 'Reward': 8}
# #164: {'Arm': '20', 'NetReward': 355201, 'Pull': 17371, 'Reward': 21}
# #165: {'Arm': '21', 'NetReward': 355232, 'Pull': 17372, 'Reward': 31}
# #166: {'Arm': '22', 'NetReward': 355238, 'Pull': 17373, 'Reward': 6}
# #167: {'Arm': '23', 'NetReward': 355253, 'Pull': 17374, 'Reward': 15}
# #168: {'Arm': '0', 'NetReward': 355260, 'Pull': 17375, 'Reward': 7}
# #169: {'Arm': '1', 'NetReward': 355281, 'Pull': 17376, 'Reward': 21}
# #170: {'Arm': '2', 'NetReward': 355303, 'Pull': 17377, 'Reward': 22}
# #171: {'Arm': '3', 'NetReward': 355317, 'Pull': 17378, 'Reward': 14}
# #172: {'Arm': '4', 'NetReward': 355332, 'Pull': 17379, 'Reward': 15}
# #173: {'Arm': '5', 'NetReward': 355349, 'Pull': 17380, 'Reward': 17}
# #174: {'Arm': '6', 'NetReward': 355365, 'Pull': 17381, 'Reward': 16}
# #175: {'Arm': '7', 'NetReward': 355389, 'Pull': 17382, 'Reward': 24}
# #176: {'Arm': '8', 'NetReward': 355403, 'Pull': 17383, 'Reward': 14}
# #177: {'Arm': '9', 'NetReward': 355429, 'Pull': 17384, 'Reward': 26}
# #178: {'Arm': '10', 'NetReward': 355448, 'Pull': 17385, 'Reward': 19}
# #179: {'Arm': '11', 'NetReward': 355469, 'Pull': 17386, 'Reward': 21}
# #180: {'Arm': '12', 'NetReward': 355475, 'Pull': 17387, 'Reward': 6}
# #181: {'Arm': '13', 'NetReward': 355492, 'Pull': 17388, 'Reward': 17}
# #182: {'Arm': '14', 'NetReward': 355496, 'Pull': 17389, 'Reward': 4}
# #183: {'Arm': '15', 'NetReward': 355518, 'Pull': 17390, 'Reward': 22}
# #184: {'Arm': '16', 'NetReward': 355534, 'Pull': 17391, 'Reward': 16}
# #185: {'Arm': '17', 'NetReward': 355542, 'Pull': 17392, 'Reward': 8}
# #186: {'Arm': '18', 'NetReward': 355551, 'Pull': 17393, 'Reward': 9}
# #187: {'Arm': '19', 'NetReward': 355558, 'Pull': 17394, 'Reward': 7}
# #188: {'Arm': '20', 'NetReward': 355576, 'Pull': 17395, 'Reward': 18}
# #189: {'Arm': '21', 'NetReward': 355613, 'Pull': 17396, 'Reward': 37}
# #190: {'Arm': '22', 'NetReward': 355621, 'Pull': 17397, 'Reward': 8}
# #191: {'Arm': '23', 'NetReward': 355635, 'Pull': 17398, 'Reward': 14}
# #192: {'Arm': '0', 'NetReward': 355642, 'Pull': 17399, 'Reward': 7}
# #193: {'Arm': '1', 'NetReward': 355657, 'Pull': 17400, 'Reward': 15}
# #194: {'Arm': '2', 'NetReward': 355676, 'Pull': 17401, 'Reward': 19}
# #195: {'Arm': '3', 'NetReward': 355689, 'Pull': 17402, 'Reward': 13}
# #196: {'Arm': '4', 'NetReward': 355713, 'Pull': 17403, 'Reward': 24}
# #197: {'Arm': '5', 'NetReward': 355726, 'Pull': 17404, 'Reward': 13}
# #198: {'Arm': '6', 'NetReward': 355740, 'Pull': 17405, 'Reward': 14}
# #199: {'Arm': '7', 'NetReward': 355761, 'Pull': 17406, 'Reward': 21}
# #200: {'Arm': '8', 'NetReward': 355774, 'Pull': 17407, 'Reward': 13}
# #201: {'Arm': '9', 'NetReward': 355794, 'Pull': 17408, 'Reward': 20}
# #202: {'Arm': '10', 'NetReward': 355818, 'Pull': 17409, 'Reward': 24}
# #203: {'Arm': '11', 'NetReward': 355831, 'Pull': 17410, 'Reward': 13}
# #204: {'Arm': '12', 'NetReward': 355834, 'Pull': 17411, 'Reward': 3}
# #205: {'Arm': '13', 'NetReward': 355855, 'Pull': 17412, 'Reward': 21}
# #206: {'Arm': '14', 'NetReward': 355864, 'Pull': 17413, 'Reward': 9}
# #207: {'Arm': '15', 'NetReward': 355883, 'Pull': 17414, 'Reward': 19}
# #208: {'Arm': '16', 'NetReward': 355895, 'Pull': 17415, 'Reward': 12}
# #209: {'Arm': '17', 'NetReward': 355908, 'Pull': 17416, 'Reward': 13}
# #210: {'Arm': '18', 'NetReward': 355922, 'Pull': 17417, 'Reward': 14}
# #211: {'Arm': '19', 'NetReward': 355930, 'Pull': 17418, 'Reward': 8}
# #212: {'Arm': '20', 'NetReward': 355958, 'Pull': 17419, 'Reward': 28}
# #213: {'Arm': '21', 'NetReward': 355985, 'Pull': 17420, 'Reward': 27}
# #214: {'Arm': '22', 'NetReward': 355995, 'Pull': 17421, 'Reward': 10}
# #215: {'Arm': '23', 'NetReward': 356002, 'Pull': 17422, 'Reward': 7}
# #216: {'Arm': '0', 'NetReward': 356011, 'Pull': 17423, 'Reward': 9}
# #217: {'Arm': '1', 'NetReward': 356025, 'Pull': 17424, 'Reward': 14}
# #218: {'Arm': '2', 'NetReward': 356051, 'Pull': 17425, 'Reward': 26}
# #219: {'Arm': '3', 'NetReward': 356062, 'Pull': 17426, 'Reward': 11}
# #220: {'Arm': '4', 'NetReward': 356083, 'Pull': 17427, 'Reward': 21}
# #221: {'Arm': '5', 'NetReward': 356106, 'Pull': 17428, 'Reward': 23}
# #222: {'Arm': '6', 'NetReward': 356122, 'Pull': 17429, 'Reward': 16}
# #223: {'Arm': '7', 'NetReward': 356143, 'Pull': 17430, 'Reward': 21}
# #224: {'Arm': '8', 'NetReward': 356159, 'Pull': 17431, 'Reward': 16}
# #225: {'Arm': '9', 'NetReward': 356181, 'Pull': 17432, 'Reward': 22}
# #226: {'Arm': '10', 'NetReward': 356201, 'Pull': 17433, 'Reward': 20}
# #227: {'Arm': '11', 'NetReward': 356215, 'Pull': 17434, 'Reward': 14}
# #228: {'Arm': '12', 'NetReward': 356220, 'Pull': 17435, 'Reward': 5}
# #229: {'Arm': '13', 'NetReward': 356242, 'Pull': 17436, 'Reward': 22}
# #230: {'Arm': '14', 'NetReward': 356247, 'Pull': 17437, 'Reward': 5}
# #231: {'Arm': '15', 'NetReward': 356270, 'Pull': 17438, 'Reward': 23}
# #232: {'Arm': '16', 'NetReward': 356283, 'Pull': 17439, 'Reward': 13}
# #233: {'Arm': '17', 'NetReward': 356299, 'Pull': 17440, 'Reward': 16}
# #234: {'Arm': '18', 'NetReward': 356312, 'Pull': 17441, 'Reward': 13}
# #235: {'Arm': '19', 'NetReward': 356317, 'Pull': 17442, 'Reward': 5}
# #236: {'Arm': '20', 'NetReward': 356342, 'Pull': 17443, 'Reward': 25}
# #237: {'Arm': '21', 'NetReward': 356370, 'Pull': 17444, 'Reward': 28}
# #238: {'Arm': '22', 'NetReward': 356379, 'Pull': 17445, 'Reward': 9}
# #239: {'Arm': '23', 'NetReward': 356396, 'Pull': 17446, 'Reward': 17}
# #240: {'Arm': '21', 'NetReward': 356424, 'Pull': 17447, 'Reward': 28}
# #241: {'Arm': '21', 'NetReward': 356448, 'Pull': 17448, 'Reward': 24}
# #242: {'Arm': '21', 'NetReward': 356475, 'Pull': 17449, 'Reward': 27}
# #243: {'Arm': '21', 'NetReward': 356505, 'Pull': 17450, 'Reward': 30}
# #244: {'Arm': '21', 'NetReward': 356535, 'Pull': 17451, 'Reward': 30}
# #245: {'Arm': '21', 'NetReward': 356558, 'Pull': 17452, 'Reward': 23}
# #246: {'Arm': '21', 'NetReward': 356582, 'Pull': 17453, 'Reward': 24}
# #247: {'Arm': '21', 'NetReward': 356614, 'Pull': 17454, 'Reward': 32}
# #248: {'Arm': '21', 'NetReward': 356632, 'Pull': 17455, 'Reward': 18}
# #249: {'Arm': '21', 'NetReward': 356658, 'Pull': 17456, 'Reward': 26}
# #250: {'Arm': '21', 'NetReward': 356685, 'Pull': 17457, 'Reward': 27}
# #251: {'Arm': '21', 'NetReward': 356711, 'Pull': 17458, 'Reward': 26}
# #252: {'Arm': '21', 'NetReward': 356732, 'Pull': 17459, 'Reward': 21}
# #253: {'Arm': '21', 'NetReward': 356761, 'Pull': 17460, 'Reward': 29}
# #254: {'Arm': '21', 'NetReward': 356786, 'Pull': 17461, 'Reward': 25}
# #255: {'Arm': '21', 'NetReward': 356809, 'Pull': 17462, 'Reward': 23}
# #256: {'Arm': '21', 'NetReward': 356831, 'Pull': 17463, 'Reward': 22}
# #257: {'Arm': '21', 'NetReward': 356861, 'Pull': 17464, 'Reward': 30}
# #258: {'Arm': '21', 'NetReward': 356884, 'Pull': 17465, 'Reward': 23}
# #259: {'Arm': '21', 'NetReward': 356918, 'Pull': 17466, 'Reward': 34}
# #260: {'Arm': '21', 'NetReward': 356937, 'Pull': 17467, 'Reward': 19}
# #261: {'Arm': '21', 'NetReward': 356954, 'Pull': 17468, 'Reward': 17}
# #262: {'Arm': '21', 'NetReward': 356984, 'Pull': 17469, 'Reward': 30}
# #263: {'Arm': '21', 'NetReward': 357008, 'Pull': 17470, 'Reward': 24}
# #264: {'Arm': '21', 'NetReward': 357038, 'Pull': 17471, 'Reward': 30}
# #265: {'Arm': '21', 'NetReward': 357057, 'Pull': 17472, 'Reward': 19}
# #266: {'Arm': '21', 'NetReward': 357084, 'Pull': 17473, 'Reward': 27}
# #267: {'Arm': '21', 'NetReward': 357109, 'Pull': 17474, 'Reward': 25}
# #268: {'Arm': '21', 'NetReward': 357128, 'Pull': 17475, 'Reward': 19}
# #269: {'Arm': '21', 'NetReward': 357148, 'Pull': 17476, 'Reward': 20}
# #270: {'Arm': '21', 'NetReward': 357163, 'Pull': 17477, 'Reward': 15}
# #271: {'Arm': '21', 'NetReward': 357186, 'Pull': 17478, 'Reward': 23}
# #272: {'Arm': '21', 'NetReward': 357210, 'Pull': 17479, 'Reward': 24}
# #273: {'Arm': '21', 'NetReward': 357226, 'Pull': 17480, 'Reward': 16}
# #274: {'Arm': '21', 'NetReward': 357247, 'Pull': 17481, 'Reward': 21}
# #275: {'Arm': '21', 'NetReward': 357267, 'Pull': 17482, 'Reward': 20}
# #276: {'Arm': '21', 'NetReward': 357294, 'Pull': 17483, 'Reward': 27}
# #277: {'Arm': '21', 'NetReward': 357318, 'Pull': 17484, 'Reward': 24}
# #278: {'Arm': '21', 'NetReward': 357339, 'Pull': 17485, 'Reward': 21}
# #279: {'Arm': '21', 'NetReward': 357356, 'Pull': 17486, 'Reward': 17}
# #280: {'Arm': '21', 'NetReward': 357377, 'Pull': 17487, 'Reward': 21}
# #281: {'Arm': '21', 'NetReward': 357400, 'Pull': 17488, 'Reward': 23}
# #282: {'Arm': '21', 'NetReward': 357429, 'Pull': 17489, 'Reward': 29}
# #283: {'Arm': '21', 'NetReward': 357457, 'Pull': 17490, 'Reward': 28}
# #284: {'Arm': '21', 'NetReward': 357482, 'Pull': 17491, 'Reward': 25}
# #285: {'Arm': '21', 'NetReward': 357500, 'Pull': 17492, 'Reward': 18}
# #286: {'Arm': '21', 'NetReward': 357529, 'Pull': 17493, 'Reward': 29}
# #287: {'Arm': '21', 'NetReward': 357559, 'Pull': 17494, 'Reward': 30}
# #288: {'Arm': '21', 'NetReward': 357581, 'Pull': 17495, 'Reward': 22}
# #289: {'Arm': '21', 'NetReward': 357607, 'Pull': 17496, 'Reward': 26}
# #290: {'Arm': '21', 'NetReward': 357634, 'Pull': 17497, 'Reward': 27}
# #291: {'Arm': '21', 'NetReward': 357660, 'Pull': 17498, 'Reward': 26}
# #292: {'Arm': '21', 'NetReward': 357685, 'Pull': 17499, 'Reward': 25}
# #293: {'Arm': '21', 'NetReward': 357701, 'Pull': 17500, 'Reward': 16}
# #294: {'Arm': '21', 'NetReward': 357729, 'Pull': 17501, 'Reward': 28}
# #295: {'Arm': '21', 'NetReward': 357754, 'Pull': 17502, 'Reward': 25}
# #296: {'Arm': '21', 'NetReward': 357781, 'Pull': 17503, 'Reward': 27}
# #297: {'Arm': '21', 'NetReward': 357806, 'Pull': 17504, 'Reward': 25}
# #298: {'Arm': '21', 'NetReward': 357826, 'Pull': 17505, 'Reward': 20}
# #299: {'Arm': '21', 'NetReward': 357850, 'Pull': 17506, 'Reward': 24}
# #300: {'Arm': '21', 'NetReward': 357871, 'Pull': 17507, 'Reward': 21}
# #301: {'Arm': '21', 'NetReward': 357885, 'Pull': 17508, 'Reward': 14}
# #302: {'Arm': '21', 'NetReward': 357911, 'Pull': 17509, 'Reward': 26}
# #303: {'Arm': '21', 'NetReward': 357935, 'Pull': 17510, 'Reward': 24}
# #304: {'Arm': '21', 'NetReward': 357962, 'Pull': 17511, 'Reward': 27}
# #305: {'Arm': '21', 'NetReward': 357985, 'Pull': 17512, 'Reward': 23}
# #306: {'Arm': '21', 'NetReward': 358005, 'Pull': 17513, 'Reward': 20}
# #307: {'Arm': '21', 'NetReward': 358027, 'Pull': 17514, 'Reward': 22}
# #308: {'Arm': '21', 'NetReward': 358055, 'Pull': 17515, 'Reward': 28}
# #309: {'Arm': '21', 'NetReward': 358083, 'Pull': 17516, 'Reward': 28}
# #310: {'Arm': '21', 'NetReward': 358112, 'Pull': 17517, 'Reward': 29}
# #311: {'Arm': '21', 'NetReward': 358139, 'Pull': 17518, 'Reward': 27}
# #312: {'Arm': '21', 'NetReward': 358161, 'Pull': 17519, 'Reward': 22}
# #313: {'Arm': '21', 'NetReward': 358192, 'Pull': 17520, 'Reward': 31}
# #314: {'Arm': '21', 'NetReward': 358213, 'Pull': 17521, 'Reward': 21}
# #315: {'Arm': '21', 'NetReward': 358238, 'Pull': 17522, 'Reward': 25}
# #316: {'Arm': '21', 'NetReward': 358262, 'Pull': 17523, 'Reward': 24}
# #317: {'Arm': '21', 'NetReward': 358294, 'Pull': 17524, 'Reward': 32}
# #318: {'Arm': '21', 'NetReward': 358321, 'Pull': 17525, 'Reward': 27}
# #319: {'Arm': '21', 'NetReward': 358353, 'Pull': 17526, 'Reward': 32}
# #320: {'Arm': '21', 'NetReward': 358374, 'Pull': 17527, 'Reward': 21}
# #321: {'Arm': '21', 'NetReward': 358405, 'Pull': 17528, 'Reward': 31}
# #322: {'Arm': '21', 'NetReward': 358420, 'Pull': 17529, 'Reward': 15}
# #323: {'Arm': '21', 'NetReward': 358444, 'Pull': 17530, 'Reward': 24}
# #324: {'Arm': '21', 'NetReward': 358472, 'Pull': 17531, 'Reward': 28}
# #325: {'Arm': '21', 'NetReward': 358497, 'Pull': 17532, 'Reward': 25}
# #326: {'Arm': '21', 'NetReward': 358528, 'Pull': 17533, 'Reward': 31}
# #327: {'Arm': '21', 'NetReward': 358555, 'Pull': 17534, 'Reward': 27}
# #328: {'Arm': '21', 'NetReward': 358578, 'Pull': 17535, 'Reward': 23}
# #329: {'Arm': '21', 'NetReward': 358598, 'Pull': 17536, 'Reward': 20}
# #330: {'Arm': '21', 'NetReward': 358623, 'Pull': 17537, 'Reward': 25}
# #331: {'Arm': '21', 'NetReward': 358658, 'Pull': 17538, 'Reward': 35}
# #332: {'Arm': '21', 'NetReward': 358687, 'Pull': 17539, 'Reward': 29}
# #333: {'Arm': '21', 'NetReward': 358709, 'Pull': 17540, 'Reward': 22}
# #334: {'Arm': '21', 'NetReward': 358730, 'Pull': 17541, 'Reward': 21}
# #335: {'Arm': '21', 'NetReward': 358756, 'Pull': 17542, 'Reward': 26}
# #336: {'Arm': '21', 'NetReward': 358779, 'Pull': 17543, 'Reward': 23}
# #337: {'Arm': '21', 'NetReward': 358812, 'Pull': 17544, 'Reward': 33}
# #338: {'Arm': '21', 'NetReward': 358834, 'Pull': 17545, 'Reward': 22}
# #339: {'Arm': '21', 'NetReward': 358860, 'Pull': 17546, 'Reward': 26}
# #340: {'Arm': '21', 'NetReward': 358887, 'Pull': 17547, 'Reward': 27}
# #341: {'Arm': '21', 'NetReward': 358918, 'Pull': 17548, 'Reward': 31}
# #342: {'Arm': '21', 'NetReward': 358949, 'Pull': 17549, 'Reward': 31}
# #343: {'Arm': '21', 'NetReward': 358976, 'Pull': 17550, 'Reward': 27}
# #344: {'Arm': '21', 'NetReward': 359002, 'Pull': 17551, 'Reward': 26}
# #345: {'Arm': '21', 'NetReward': 359021, 'Pull': 17552, 'Reward': 19}
# #346: {'Arm': '21', 'NetReward': 359045, 'Pull': 17553, 'Reward': 24}
# #347: {'Arm': '21', 'NetReward': 359070, 'Pull': 17554, 'Reward': 25}
# #348: {'Arm': '21', 'NetReward': 359098, 'Pull': 17555, 'Reward': 28}
# #349: {'Arm': '21', 'NetReward': 359120, 'Pull': 17556, 'Reward': 22}
# #350: {'Arm': '21', 'NetReward': 359139, 'Pull': 17557, 'Reward': 19}
# #351: {'Arm': '21', 'NetReward': 359163, 'Pull': 17558, 'Reward': 24}
# #352: {'Arm': '21', 'NetReward': 359191, 'Pull': 17559, 'Reward': 28}
# #353: {'Arm': '21', 'NetReward': 359216, 'Pull': 17560, 'Reward': 25}
# #354: {'Arm': '21', 'NetReward': 359244, 'Pull': 17561, 'Reward': 28}
# #355: {'Arm': '21', 'NetReward': 359264, 'Pull': 17562, 'Reward': 20}
# #356: {'Arm': '21', 'NetReward': 359289, 'Pull': 17563, 'Reward': 25}
# #357: {'Arm': '21', 'NetReward': 359313, 'Pull': 17564, 'Reward': 24}
# #358: {'Arm': '21', 'NetReward': 359338, 'Pull': 17565, 'Reward': 25}
# #359: {'Arm': '21', 'NetReward': 359368, 'Pull': 17566, 'Reward': 30}
# #360: {'Arm': '21', 'NetReward': 359390, 'Pull': 17567, 'Reward': 22}
# #361: {'Arm': '21', 'NetReward': 359415, 'Pull': 17568, 'Reward': 25}
# #362: {'Arm': '21', 'NetReward': 359438, 'Pull': 17569, 'Reward': 23}
# #363: {'Arm': '21', 'NetReward': 359460, 'Pull': 17570, 'Reward': 22}
# #364: {'Arm': '21', 'NetReward': 359485, 'Pull': 17571, 'Reward': 25}
# #365: {'Arm': '21', 'NetReward': 359510, 'Pull': 17572, 'Reward': 25}
# #366: {'Arm': '21', 'NetReward': 359526, 'Pull': 17573, 'Reward': 16}
# #367: {'Arm': '21', 'NetReward': 359554, 'Pull': 17574, 'Reward': 28}
# #368: {'Arm': '21', 'NetReward': 359580, 'Pull': 17575, 'Reward': 26}
# #369: {'Arm': '21', 'NetReward': 359598, 'Pull': 17576, 'Reward': 18}
# #370: {'Arm': '21', 'NetReward': 359627, 'Pull': 17577, 'Reward': 29}
# #371: {'Arm': '21', 'NetReward': 359652, 'Pull': 17578, 'Reward': 25}
# #372: {'Arm': '21', 'NetReward': 359674, 'Pull': 17579, 'Reward': 22}
# #373: {'Arm': '21', 'NetReward': 359705, 'Pull': 17580, 'Reward': 31}
# #374: {'Arm': '21', 'NetReward': 359727, 'Pull': 17581, 'Reward': 22}
# #375: {'Arm': '21', 'NetReward': 359745, 'Pull': 17582, 'Reward': 18}
# #376: {'Arm': '21', 'NetReward': 359774, 'Pull': 17583, 'Reward': 29}
# #377: {'Arm': '21', 'NetReward': 359799, 'Pull': 17584, 'Reward': 25}
# #378: {'Arm': '21', 'NetReward': 359819, 'Pull': 17585, 'Reward': 20}
# #379: {'Arm': '21', 'NetReward': 359836, 'Pull': 17586, 'Reward': 17}
# #380: {'Arm': '21', 'NetReward': 359859, 'Pull': 17587, 'Reward': 23}
# #381: {'Arm': '21', 'NetReward': 359886, 'Pull': 17588, 'Reward': 27}
# #382: {'Arm': '21', 'NetReward': 359909, 'Pull': 17589, 'Reward': 23}
# #383: {'Arm': '21', 'NetReward': 359937, 'Pull': 17590, 'Reward': 28}
# #384: {'Arm': '21', 'NetReward': 359953, 'Pull': 17591, 'Reward': 16}
# #385: {'Arm': '21', 'NetReward': 359974, 'Pull': 17592, 'Reward': 21}
# #386: {'Arm': '21', 'NetReward': 359997, 'Pull': 17593, 'Reward': 23}
# #387: {'Arm': '21', 'NetReward': 360020, 'Pull': 17594, 'Reward': 23}
# #388: {'Arm': '21', 'NetReward': 360045, 'Pull': 17595, 'Reward': 25}
# #389: {'Arm': '21', 'NetReward': 360067, 'Pull': 17596, 'Reward': 22}
# #390: {'Arm': '21', 'NetReward': 360089, 'Pull': 17597, 'Reward': 22}
# #391: {'Arm': '21', 'NetReward': 360115, 'Pull': 17598, 'Reward': 26}
# #392: {'Arm': '21', 'NetReward': 360138, 'Pull': 17599, 'Reward': 23}
# #393: {'Arm': '21', 'NetReward': 360164, 'Pull': 17600, 'Reward': 26}
# #394: {'Arm': '21', 'NetReward': 360191, 'Pull': 17601, 'Reward': 27}
# #395: {'Arm': '21', 'NetReward': 360219, 'Pull': 17602, 'Reward': 28}
# #396: {'Arm': '21', 'NetReward': 360247, 'Pull': 17603, 'Reward': 28}
# #397: {'Arm': '21', 'NetReward': 360273, 'Pull': 17604, 'Reward': 26}
# #398: {'Arm': '21', 'NetReward': 360294, 'Pull': 17605, 'Reward': 21}
# #399: {'Arm': '21', 'NetReward': 360317, 'Pull': 17606, 'Reward': 23}
# #400: {'Arm': '21', 'NetReward': 360345, 'Pull': 17607, 'Reward': 28}
# #401: {'Arm': '21', 'NetReward': 360373, 'Pull': 17608, 'Reward': 28}
# #402: {'Arm': '21', 'NetReward': 360396, 'Pull': 17609, 'Reward': 23}
# #403: {'Arm': '21', 'NetReward': 360427, 'Pull': 17610, 'Reward': 31}
# #404: {'Arm': '21', 'NetReward': 360449, 'Pull': 17611, 'Reward': 22}
# #405: {'Arm': '21', 'NetReward': 360472, 'Pull': 17612, 'Reward': 23}
# #406: {'Arm': '21', 'NetReward': 360493, 'Pull': 17613, 'Reward': 21}
# #407: {'Arm': '21', 'NetReward': 360521, 'Pull': 17614, 'Reward': 28}
# #408: {'Arm': '21', 'NetReward': 360547, 'Pull': 17615, 'Reward': 26}
# #409: {'Arm': '21', 'NetReward': 360578, 'Pull': 17616, 'Reward': 31}
# #410: {'Arm': '21', 'NetReward': 360612, 'Pull': 17617, 'Reward': 34}
# #411: {'Arm': '21', 'NetReward': 360635, 'Pull': 17618, 'Reward': 23}
# #412: {'Arm': '21', 'NetReward': 360658, 'Pull': 17619, 'Reward': 23}
# #413: {'Arm': '21', 'NetReward': 360682, 'Pull': 17620, 'Reward': 24}
# #414: {'Arm': '21', 'NetReward': 360703, 'Pull': 17621, 'Reward': 21}
# #415: {'Arm': '21', 'NetReward': 360725, 'Pull': 17622, 'Reward': 22}
# #416: {'Arm': '21', 'NetReward': 360743, 'Pull': 17623, 'Reward': 18}
# #417: {'Arm': '21', 'NetReward': 360767, 'Pull': 17624, 'Reward': 24}
# #418: {'Arm': '21', 'NetReward': 360797, 'Pull': 17625, 'Reward': 30}
# #419: {'Arm': '21', 'NetReward': 360820, 'Pull': 17626, 'Reward': 23}
# #420: {'Arm': '21', 'NetReward': 360847, 'Pull': 17627, 'Reward': 27}
# #421: {'Arm': '21', 'NetReward': 360869, 'Pull': 17628, 'Reward': 22}
# #422: {'Arm': '21', 'NetReward': 360889, 'Pull': 17629, 'Reward': 20}
# #423: {'Arm': '21', 'NetReward': 360911, 'Pull': 17630, 'Reward': 22}
# #424: {'Arm': '21', 'NetReward': 360943, 'Pull': 17631, 'Reward': 32}
# #425: {'Arm': '21', 'NetReward': 360973, 'Pull': 17632, 'Reward': 30}
# #426: {'Arm': '21', 'NetReward': 361000, 'Pull': 17633, 'Reward': 27}
# #427: {'Arm': '21', 'NetReward': 361026, 'Pull': 17634, 'Reward': 26}
# #428: {'Arm': '21', 'NetReward': 361054, 'Pull': 17635, 'Reward': 28}
# #429: {'Arm': '21', 'NetReward': 361076, 'Pull': 17636, 'Reward': 22}
# #430: {'Arm': '21', 'NetReward': 361100, 'Pull': 17637, 'Reward': 24}
# #431: {'Arm': '21', 'NetReward': 361124, 'Pull': 17638, 'Reward': 24}
# #432: {'Arm': '21', 'NetReward': 361149, 'Pull': 17639, 'Reward': 25}
# #433: {'Arm': '21', 'NetReward': 361179, 'Pull': 17640, 'Reward': 30}
# #434: {'Arm': '21', 'NetReward': 361205, 'Pull': 17641, 'Reward': 26}
# #435: {'Arm': '21', 'NetReward': 361229, 'Pull': 17642, 'Reward': 24}
# #436: {'Arm': '21', 'NetReward': 361251, 'Pull': 17643, 'Reward': 22}
# #437: {'Arm': '21', 'NetReward': 361281, 'Pull': 17644, 'Reward': 30}
# #438: {'Arm': '21', 'NetReward': 361302, 'Pull': 17645, 'Reward': 21}
# #439: {'Arm': '21', 'NetReward': 361324, 'Pull': 17646, 'Reward': 22}
# #440: {'Arm': '21', 'NetReward': 361355, 'Pull': 17647, 'Reward': 31}
# #441: {'Arm': '21', 'NetReward': 361387, 'Pull': 17648, 'Reward': 32}
# #442: {'Arm': '21', 'NetReward': 361413, 'Pull': 17649, 'Reward': 26}
# #443: {'Arm': '21', 'NetReward': 361434, 'Pull': 17650, 'Reward': 21}
# #444: {'Arm': '21', 'NetReward': 361457, 'Pull': 17651, 'Reward': 23}
# #445: {'Arm': '21', 'NetReward': 361477, 'Pull': 17652, 'Reward': 20}
# #446: {'Arm': '21', 'NetReward': 361506, 'Pull': 17653, 'Reward': 29}
# #447: {'Arm': '21', 'NetReward': 361529, 'Pull': 17654, 'Reward': 23}
# #448: {'Arm': '21', 'NetReward': 361555, 'Pull': 17655, 'Reward': 26}
# #449: {'Arm': '21', 'NetReward': 361580, 'Pull': 17656, 'Reward': 25}
# #450: {'Arm': '21', 'NetReward': 361603, 'Pull': 17657, 'Reward': 23}
# #451: {'Arm': '21', 'NetReward': 361631, 'Pull': 17658, 'Reward': 28}
# #452: {'Arm': '21', 'NetReward': 361650, 'Pull': 17659, 'Reward': 19}
# #453: {'Arm': '21', 'NetReward': 361676, 'Pull': 17660, 'Reward': 26}
# #454: {'Arm': '21', 'NetReward': 361706, 'Pull': 17661, 'Reward': 30}
# #455: {'Arm': '21', 'NetReward': 361729, 'Pull': 17662, 'Reward': 23}
# #456: {'Arm': '21', 'NetReward': 361754, 'Pull': 17663, 'Reward': 25}
# #457: {'Arm': '21', 'NetReward': 361773, 'Pull': 17664, 'Reward': 19}
# #458: {'Arm': '21', 'NetReward': 361807, 'Pull': 17665, 'Reward': 34}
# #459: {'Arm': '21', 'NetReward': 361833, 'Pull': 17666, 'Reward': 26}
# #460: {'Arm': '21', 'NetReward': 361857, 'Pull': 17667, 'Reward': 24}
# #461: {'Arm': '21', 'NetReward': 361886, 'Pull': 17668, 'Reward': 29}
# #462: {'Arm': '21', 'NetReward': 361919, 'Pull': 17669, 'Reward': 33}
# #463: {'Arm': '21', 'NetReward': 361940, 'Pull': 17670, 'Reward': 21}
# #464: {'Arm': '21', 'NetReward': 361965, 'Pull': 17671, 'Reward': 25}
# #465: {'Arm': '21', 'NetReward': 361991, 'Pull': 17672, 'Reward': 26}
# #466: {'Arm': '21', 'NetReward': 362016, 'Pull': 17673, 'Reward': 25}
# #467: {'Arm': '21', 'NetReward': 362051, 'Pull': 17674, 'Reward': 35}
# #468: {'Arm': '21', 'NetReward': 362081, 'Pull': 17675, 'Reward': 30}
# #469: {'Arm': '21', 'NetReward': 362108, 'Pull': 17676, 'Reward': 27}
# #470: {'Arm': '21', 'NetReward': 362130, 'Pull': 17677, 'Reward': 22}
# #471: {'Arm': '21', 'NetReward': 362157, 'Pull': 17678, 'Reward': 27}
# #472: {'Arm': '21', 'NetReward': 362176, 'Pull': 17679, 'Reward': 19}
# #473: {'Arm': '21', 'NetReward': 362202, 'Pull': 17680, 'Reward': 26}
# #474: {'Arm': '21', 'NetReward': 362228, 'Pull': 17681, 'Reward': 26}
# #475: {'Arm': '21', 'NetReward': 362251, 'Pull': 17682, 'Reward': 23}
# #476: {'Arm': '21', 'NetReward': 362273, 'Pull': 17683, 'Reward': 22}
# #477: {'Arm': '21', 'NetReward': 362298, 'Pull': 17684, 'Reward': 25}
# #478: {'Arm': '21', 'NetReward': 362317, 'Pull': 17685, 'Reward': 19}
# #479: {'Arm': '21', 'NetReward': 362335, 'Pull': 17686, 'Reward': 18}
# #480: {'Arm': '21', 'NetReward': 362351, 'Pull': 17687, 'Reward': 16}
# #481: {'Arm': '21', 'NetReward': 362379, 'Pull': 17688, 'Reward': 28}
# #482: {'Arm': '21', 'NetReward': 362413, 'Pull': 17689, 'Reward': 34}
# #483: {'Arm': '21', 'NetReward': 362425, 'Pull': 17690, 'Reward': 12}
# #484: {'Arm': '21', 'NetReward': 362449, 'Pull': 17691, 'Reward': 24}
# #485: {'Arm': '21', 'NetReward': 362472, 'Pull': 17692, 'Reward': 23}
# #486: {'Arm': '21', 'NetReward': 362505, 'Pull': 17693, 'Reward': 33}
# #487: {'Arm': '21', 'NetReward': 362530, 'Pull': 17694, 'Reward': 25}
# #488: {'Arm': '21', 'NetReward': 362559, 'Pull': 17695, 'Reward': 29}
# #489: {'Arm': '21', 'NetReward': 362579, 'Pull': 17696, 'Reward': 20}
# #490: {'Arm': '21', 'NetReward': 362599, 'Pull': 17697, 'Reward': 20}
# #491: {'Arm': '21', 'NetReward': 362627, 'Pull': 17698, 'Reward': 28}
# #492: {'Arm': '21', 'NetReward': 362648, 'Pull': 17699, 'Reward': 21}
# #493: {'Arm': '21', 'NetReward': 362675, 'Pull': 17700, 'Reward': 27}
# #494: {'Arm': '21', 'NetReward': 362692, 'Pull': 17701, 'Reward': 17}
# #495: {'Arm': '21', 'NetReward': 362712, 'Pull': 17702, 'Reward': 20}
# #496: {'Arm': '21', 'NetReward': 362734, 'Pull': 17703, 'Reward': 22}
# #497: {'Arm': '21', 'NetReward': 362761, 'Pull': 17704, 'Reward': 27}
# #498: {'Arm': '21', 'NetReward': 362774, 'Pull': 17705, 'Reward': 13}
# #499: {'Arm': '21', 'NetReward': 362802, 'Pull': 17706, 'Reward': 28}
#
# ##########################################################################################
# Total Runs
# ##########################################################################################
#
# {'Arm': 0, 'Output_Arm': '0', 'N_List': [2, 5, 8, 9, 5, 3, 8, 7, 7, 9], 'Reward_List': [2, 5, 8, 9, 5, 3, 8, 7, 7, 9], 'Round_List': [0, 24, 48, 72, 96, 120, 144, 168, 192, 216], 'Total_Reward': 63, 'Avg_N': 6.3, 'Avg_Reward': 6.3}
# {'Arm': 1, 'Output_Arm': '1', 'N_List': [16, 16, 15, 20, 16, 13, 12, 21, 15, 14], 'Reward_List': [16, 16, 15, 20, 16, 13, 12, 21, 15, 14], 'Round_List': [1, 25, 49, 73, 97, 121, 145, 169, 193, 217], 'Total_Reward': 158, 'Avg_N': 15.8, 'Avg_Reward': 15.8}
# {'Arm': 2, 'Output_Arm': '2', 'N_List': [14, 25, 26, 18, 22, 13, 33, 22, 19, 26], 'Reward_List': [14, 25, 26, 18, 22, 13, 33, 22, 19, 26], 'Round_List': [2, 26, 50, 74, 98, 122, 146, 170, 194, 218], 'Total_Reward': 218, 'Avg_N': 21.8, 'Avg_Reward': 21.8}
# {'Arm': 3, 'Output_Arm': '3', 'N_List': [27, 14, 23, 13, 15, 11, 16, 14, 13, 11], 'Reward_List': [27, 14, 23, 13, 15, 11, 16, 14, 13, 11], 'Round_List': [3, 27, 51, 75, 99, 123, 147, 171, 195, 219], 'Total_Reward': 157, 'Avg_N': 15.7, 'Avg_Reward': 15.7}
# {'Arm': 4, 'Output_Arm': '4', 'N_List': [12, 11, 22, 17, 24, 13, 17, 15, 24, 21], 'Reward_List': [12, 11, 22, 17, 24, 13, 17, 15, 24, 21], 'Round_List': [4, 28, 52, 76, 100, 124, 148, 172, 196, 220], 'Total_Reward': 176, 'Avg_N': 17.6, 'Avg_Reward': 17.6}
# {'Arm': 5, 'Output_Arm': '5', 'N_List': [22, 25, 22, 14, 17, 26, 19, 17, 13, 23], 'Reward_List': [22, 25, 22, 14, 17, 26, 19, 17, 13, 23], 'Round_List': [5, 29, 53, 77, 101, 125, 149, 173, 197, 221], 'Total_Reward': 198, 'Avg_N': 19.8, 'Avg_Reward': 19.8}
# {'Arm': 6, 'Output_Arm': '6', 'N_List': [13, 13, 12, 18, 12, 20, 11, 16, 14, 16], 'Reward_List': [13, 13, 12, 18, 12, 20, 11, 16, 14, 16], 'Round_List': [6, 30, 54, 78, 102, 126, 150, 174, 198, 222], 'Total_Reward': 145, 'Avg_N': 14.5, 'Avg_Reward': 14.5}
# {'Arm': 7, 'Output_Arm': '7', 'N_List': [23, 16, 15, 20, 18, 15, 22, 24, 21, 21], 'Reward_List': [23, 16, 15, 20, 18, 15, 22, 24, 21, 21], 'Round_List': [7, 31, 55, 79, 103, 127, 151, 175, 199, 223], 'Total_Reward': 195, 'Avg_N': 19.5, 'Avg_Reward': 19.5}
# {'Arm': 8, 'Output_Arm': '8', 'N_List': [15, 21, 4, 14, 10, 10, 20, 14, 13, 16], 'Reward_List': [15, 21, 4, 14, 10, 10, 20, 14, 13, 16], 'Round_List': [8, 32, 56, 80, 104, 128, 152, 176, 200, 224], 'Total_Reward': 137, 'Avg_N': 13.7, 'Avg_Reward': 13.7}
# {'Arm': 9, 'Output_Arm': '9', 'N_List': [15, 15, 20, 17, 19, 15, 21, 26, 20, 22], 'Reward_List': [15, 15, 20, 17, 19, 15, 21, 26, 20, 22], 'Round_List': [9, 33, 57, 81, 105, 129, 153, 177, 201, 225], 'Total_Reward': 190, 'Avg_N': 19.0, 'Avg_Reward': 19.0}
# {'Arm': 10, 'Output_Arm': '10', 'N_List': [25, 20, 24, 14, 19, 20, 19, 19, 24, 20], 'Reward_List': [25, 20, 24, 14, 19, 20, 19, 19, 24, 20], 'Round_List': [10, 34, 58, 82, 106, 130, 154, 178, 202, 226], 'Total_Reward': 204, 'Avg_N': 20.4, 'Avg_Reward': 20.4}
# {'Arm': 11, 'Output_Arm': '11', 'N_List': [6, 10, 23, 12, 11, 15, 8, 21, 13, 14], 'Reward_List': [6, 10, 23, 12, 11, 15, 8, 21, 13, 14], 'Round_List': [11, 35, 59, 83, 107, 131, 155, 179, 203, 227], 'Total_Reward': 133, 'Avg_N': 13.3, 'Avg_Reward': 13.3}
# {'Arm': 12, 'Output_Arm': '12', 'N_List': [8, 7, 4, 7, 5, 9, 6, 6, 3, 5], 'Reward_List': [8, 7, 4, 7, 5, 9, 6, 6, 3, 5], 'Round_List': [12, 36, 60, 84, 108, 132, 156, 180, 204, 228], 'Total_Reward': 60, 'Avg_N': 6.0, 'Avg_Reward': 6.0}
# {'Arm': 13, 'Output_Arm': '13', 'N_List': [21, 31, 22, 27, 13, 22, 27, 17, 21, 22], 'Reward_List': [21, 31, 22, 27, 13, 22, 27, 17, 21, 22], 'Round_List': [13, 37, 61, 85, 109, 133, 157, 181, 205, 229], 'Total_Reward': 223, 'Avg_N': 22.3, 'Avg_Reward': 22.3}
# {'Arm': 14, 'Output_Arm': '14', 'N_List': [9, 7, 12, 2, 3, 7, 3, 4, 9, 5], 'Reward_List': [9, 7, 12, 2, 3, 7, 3, 4, 9, 5], 'Round_List': [14, 38, 62, 86, 110, 134, 158, 182, 206, 230], 'Total_Reward': 61, 'Avg_N': 6.1, 'Avg_Reward': 6.1}
# {'Arm': 15, 'Output_Arm': '15', 'N_List': [23, 17, 18, 20, 25, 23, 16, 22, 19, 23], 'Reward_List': [23, 17, 18, 20, 25, 23, 16, 22, 19, 23], 'Round_List': [15, 39, 63, 87, 111, 135, 159, 183, 207, 231], 'Total_Reward': 206, 'Avg_N': 20.6, 'Avg_Reward': 20.6}
# {'Arm': 16, 'Output_Arm': '16', 'N_List': [19, 15, 14, 15, 8, 11, 17, 16, 12, 13], 'Reward_List': [19, 15, 14, 15, 8, 11, 17, 16, 12, 13], 'Round_List': [16, 40, 64, 88, 112, 136, 160, 184, 208, 232], 'Total_Reward': 140, 'Avg_N': 14.0, 'Avg_Reward': 14.0}
# {'Arm': 17, 'Output_Arm': '17', 'N_List': [8, 11, 10, 9, 15, 5, 11, 8, 13, 16], 'Reward_List': [8, 11, 10, 9, 15, 5, 11, 8, 13, 16], 'Round_List': [17, 41, 65, 89, 113, 137, 161, 185, 209, 233], 'Total_Reward': 106, 'Avg_N': 10.6, 'Avg_Reward': 10.6}
# {'Arm': 18, 'Output_Arm': '18', 'N_List': [14, 15, 12, 18, 10, 10, 11, 9, 14, 13], 'Reward_List': [14, 15, 12, 18, 10, 10, 11, 9, 14, 13], 'Round_List': [18, 42, 66, 90, 114, 138, 162, 186, 210, 234], 'Total_Reward': 126, 'Avg_N': 12.6, 'Avg_Reward': 12.6}
# {'Arm': 19, 'Output_Arm': '19', 'N_List': [7, 8, 4, 7, 6, 8, 8, 7, 8, 5], 'Reward_List': [7, 8, 4, 7, 6, 8, 8, 7, 8, 5], 'Round_List': [19, 43, 67, 91, 115, 139, 163, 187, 211, 235], 'Total_Reward': 68, 'Avg_N': 6.8, 'Avg_Reward': 6.8}
# {'Arm': 20, 'Output_Arm': '20', 'N_List': [24, 24, 16, 23, 22, 12, 21, 18, 28, 25], 'Reward_List': [24, 24, 16, 23, 22, 12, 21, 18, 28, 25], 'Round_List': [20, 44, 68, 92, 116, 140, 164, 188, 212, 236], 'Total_Reward': 213, 'Avg_N': 21.3, 'Avg_Reward': 21.3}
# {'Arm': 21, 'Output_Arm': '21', 'N_List': [25, 18, 30, 28, 25, 19, 31, 37, 27, 28], 'Reward_List': [25, 18, 30, 28, 25, 19, 31, 37, 27, 28, 28, 24, 27, 30, 30, 23, 24, 32, 18, 26, 27, 26, 21, 29, 25, 23, 22, 30, 23, 34, 19, 17, 30, 24, 30, 19, 27, 25, 19, 20, 15, 23, 24, 16, 21, 20, 27, 24, 21, 17, 21, 23, 29, 28, 25, 18, 29, 30, 22, 26, 27, 26, 25, 16, 28, 25, 27, 25, 20, 24, 21, 14, 26, 24, 27, 23, 20, 22, 28, 28, 29, 27, 22, 31, 21, 25, 24, 32, 27, 32, 21, 31, 15, 24, 28, 25, 31, 27, 23, 20, 25, 35, 29, 22, 21, 26, 23, 33, 22, 26, 27, 31, 31, 27, 26, 19, 24, 25, 28, 22, 19, 24, 28, 25, 28, 20, 25, 24, 25, 30, 22, 25, 23, 22, 25, 25, 16, 28, 26, 18, 29, 25, 22, 31, 22, 18, 29, 25, 20, 17, 23, 27, 23, 28, 16, 21, 23, 23, 25, 22, 22, 26, 23, 26, 27, 28, 28, 26, 21, 23, 28, 28, 23, 31, 22, 23, 21, 28, 26, 31, 34, 23, 23, 24, 21, 22, 18, 24, 30, 23, 27, 22, 20, 22, 32, 30, 27, 26, 28, 22, 24, 24, 25, 30, 26, 24, 22, 30, 21, 22, 31, 32, 26, 21, 23, 20, 29, 23, 26, 25, 23, 28, 19, 26, 30, 23, 25, 19, 34, 26, 24, 29, 33, 21, 25, 26, 25, 35, 30, 27, 22, 27, 19, 26, 26, 23, 22, 25, 19, 18, 16, 28, 34, 12, 24, 23, 33, 25, 29, 20, 20, 28, 21, 27, 17, 20, 22, 27, 13, 28], 'Round_List': [21, 45, 69, 93, 117, 141, 165, 189, 213, 237, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499], 'Total_Reward': 6674, 'Avg_N': 26.8, 'Avg_Reward': 24.71851851851852}
# {'Arm': 22, 'Output_Arm': '22', 'N_List': [11, 10, 10, 5, 8, 5, 6, 8, 10, 9], 'Reward_List': [11, 10, 10, 5, 8, 5, 6, 8, 10, 9], 'Round_List': [22, 46, 70, 94, 118, 142, 166, 190, 214, 238], 'Total_Reward': 82, 'Avg_N': 8.2, 'Avg_Reward': 8.2}
# {'Arm': 23, 'Output_Arm': '23', 'N_List': [21, 13, 14, 16, 10, 17, 15, 14, 7, 17], 'Reward_List': [21, 13, 14, 16, 10, 17, 15, 14, 7, 17], 'Round_List': [23, 47, 71, 95, 119, 143, 167, 191, 215, 239], 'Total_Reward': 144, 'Avg_N': 14.4, 'Avg_Reward': 14.4}
#
# ##########################################################################################
# Regret Plot
# ##########################################################################################
#
# Best Arm Identified: {'Arm': 21, 'Output_Arm': '21', 'N_List': [25, 18, 30, 28, 25, 19, 31, 37, 27, 28], 'Reward_List': [25, 18, 30, 28, 25, 19, 31, 37, 27, 28, 28, 24, 27, 30, 30, 23, 24, 32, 18, 26, 27, 26, 21, 29, 25, 23, 22, 30, 23, 34, 19, 17, 30, 24, 30, 19, 27, 25, 19, 20, 15, 23, 24, 16, 21, 20, 27, 24, 21, 17, 21, 23, 29, 28, 25, 18, 29, 30, 22, 26, 27, 26, 25, 16, 28, 25, 27, 25, 20, 24, 21, 14, 26, 24, 27, 23, 20, 22, 28, 28, 29, 27, 22, 31, 21, 25, 24, 32, 27, 32, 21, 31, 15, 24, 28, 25, 31, 27, 23, 20, 25, 35, 29, 22, 21, 26, 23, 33, 22, 26, 27, 31, 31, 27, 26, 19, 24, 25, 28, 22, 19, 24, 28, 25, 28, 20, 25, 24, 25, 30, 22, 25, 23, 22, 25, 25, 16, 28, 26, 18, 29, 25, 22, 31, 22, 18, 29, 25, 20, 17, 23, 27, 23, 28, 16, 21, 23, 23, 25, 22, 22, 26, 23, 26, 27, 28, 28, 26, 21, 23, 28, 28, 23, 31, 22, 23, 21, 28, 26, 31, 34, 23, 23, 24, 21, 22, 18, 24, 30, 23, 27, 22, 20, 22, 32, 30, 27, 26, 28, 22, 24, 24, 25, 30, 26, 24, 22, 30, 21, 22, 31, 32, 26, 21, 23, 20, 29, 23, 26, 25, 23, 28, 19, 26, 30, 23, 25, 19, 34, 26, 24, 29, 33, 21, 25, 26, 25, 35, 30, 27, 22, 27, 19, 26, 26, 23, 22, 25, 19, 18, 16, 28, 34, 12, 24, 23, 33, 25, 29, 20, 20, 28, 21, 27, 17, 20, 22, 27, 13, 28], 'Round_List': [21, 45, 69, 93, 117, 141, 165, 189, 213, 237, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499], 'Total_Reward': 6674, 'Avg_N': 26.8, 'Avg_Reward': 24.71851851851852}
