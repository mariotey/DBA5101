# %%
import os
import numpy as np
import math
import time
from server_pull import pull
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import shapiro
# os.getcwd()

# %%
# output = pull('user40','XEq6wByD',2)
# output
# Out:
# {'Arm': '2', 'NetReward': 232457, 'Pull': 10702, 'Reward': 22}

# %% [markdown]
# # Arm distribution

# %%
# Define your function, pull(n), which generates an output integer
# def pull2(n):
#     # Replace this with your actual function logic
#     # For demonstration purposes, returning a random value
#     import random
#     return random.randint(1, 100)

# Create an empty DataFrame to store the output
df = pd.DataFrame()

# Loop through values of n from 0 to 24
for n in range(24):
    # Call the pull function 100 times for each n and store the output in a list
    outputs = [pull('user40','XEq6wByD', n) for _ in range(100)]
    # outputs = [pull2(n) for _ in range(100)]
    
    # Create a new column in the DataFrame with the outputs for the current n
    df[f'arm_{n}'] = outputs

# Display the DataFrame
df.to_csv('arm_distribution.csv')
print(df)
# Out:
#                                                 arm_0  \
# 0   {'Arm': '0', 'NetReward': 232462, 'Pull': 1070...
# 1   {'Arm': '0', 'NetReward': 232473, 'Pull': 1070...
# 2   {'Arm': '0', 'NetReward': 232476, 'Pull': 1070...
# 3   {'Arm': '0', 'NetReward': 232482, 'Pull': 1070...
# 4   {'Arm': '0', 'NetReward': 232490, 'Pull': 1070...
# ..                                                ...
# 95  {'Arm': '0', 'NetReward': 233142, 'Pull': 1079...
# 96  {'Arm': '0', 'NetReward': 233150, 'Pull': 1079...
# 97  {'Arm': '0', 'NetReward': 233155, 'Pull': 1080...
# 98  {'Arm': '0', 'NetReward': 233163, 'Pull': 1080...
# 99  {'Arm': '0', 'NetReward': 233167, 'Pull': 1080...
#
#                                                 arm_1  \
# 0   {'Arm': '1', 'NetReward': 233184, 'Pull': 1080...
# 1   {'Arm': '1', 'NetReward': 233197, 'Pull': 1080...
# 2   {'Arm': '1', 'NetReward': 233213, 'Pull': 1080...
# 3   {'Arm': '1', 'NetReward': 233232, 'Pull': 1080...
# 4   {'Arm': '1', 'NetReward': 233252, 'Pull': 1080...
# ..                                                ...
# 95  {'Arm': '1', 'NetReward': 234736, 'Pull': 1089...
# 96  {'Arm': '1', 'NetReward': 234747, 'Pull': 1089...
# 97  {'Arm': '1', 'NetReward': 234766, 'Pull': 1090...
# 98  {'Arm': '1', 'NetReward': 234785, 'Pull': 1090...
# 99  {'Arm': '1', 'NetReward': 234802, 'Pull': 1090...
#
#                                                 arm_2  \
# 0   {'Arm': '2', 'NetReward': 234831, 'Pull': 1090...
# 1   {'Arm': '2', 'NetReward': 234853, 'Pull': 1090...
# 2   {'Arm': '2', 'NetReward': 234874, 'Pull': 1090...
# 3   {'Arm': '2', 'NetReward': 234893, 'Pull': 1090...
# 4   {'Arm': '2', 'NetReward': 234910, 'Pull': 1090...
# ..                                                ...
# 95  {'Arm': '2', 'NetReward': 236900, 'Pull': 1099...
# 96  {'Arm': '2', 'NetReward': 236931, 'Pull': 1099...
# 97  {'Arm': '2', 'NetReward': 236955, 'Pull': 1100...
# 98  {'Arm': '2', 'NetReward': 236974, 'Pull': 1100...
# 99  {'Arm': '2', 'NetReward': 237000, 'Pull': 1100...
#
#                                                 arm_3  \
# 0   {'Arm': '3', 'NetReward': 237015, 'Pull': 1100...
# 1   {'Arm': '3', 'NetReward': 237033, 'Pull': 1100...
# 2   {'Arm': '3', 'NetReward': 237057, 'Pull': 1100...
# 3   {'Arm': '3', 'NetReward': 237069, 'Pull': 1100...
# 4   {'Arm': '3', 'NetReward': 237084, 'Pull': 1100...
# ..                                                ...
# 95  {'Arm': '3', 'NetReward': 238780, 'Pull': 1109...
# 96  {'Arm': '3', 'NetReward': 238803, 'Pull': 1109...
# 97  {'Arm': '3', 'NetReward': 238827, 'Pull': 1110...
# 98  {'Arm': '3', 'NetReward': 238838, 'Pull': 1110...
# 99  {'Arm': '3', 'NetReward': 238852, 'Pull': 1110...
#
#                                                 arm_4  \
# 0   {'Arm': '4', 'NetReward': 238877, 'Pull': 1110...
# 1   {'Arm': '4', 'NetReward': 238896, 'Pull': 1110...
# 2   {'Arm': '4', 'NetReward': 238916, 'Pull': 1110...
# 3   {'Arm': '4', 'NetReward': 238929, 'Pull': 1110...
# 4   {'Arm': '4', 'NetReward': 238945, 'Pull': 1110...
# ..                                                ...
# 95  {'Arm': '4', 'NetReward': 240613, 'Pull': 1119...
# 96  {'Arm': '4', 'NetReward': 240628, 'Pull': 1119...
# 97  {'Arm': '4', 'NetReward': 240655, 'Pull': 1120...
# 98  {'Arm': '4', 'NetReward': 240673, 'Pull': 1120...
# 99  {'Arm': '4', 'NetReward': 240695, 'Pull': 1120...
#
#                                                 arm_5  \
# 0   {'Arm': '5', 'NetReward': 240712, 'Pull': 1120...
# 1   {'Arm': '5', 'NetReward': 240740, 'Pull': 1120...
# 2   {'Arm': '5', 'NetReward': 240767, 'Pull': 1120...
# 3   {'Arm': '5', 'NetReward': 240788, 'Pull': 1120...
# 4   {'Arm': '5', 'NetReward': 240814, 'Pull': 1120...
# ..                                                ...
# 95  {'Arm': '5', 'NetReward': 242752, 'Pull': 1129...
# 96  {'Arm': '5', 'NetReward': 242772, 'Pull': 1129...
# 97  {'Arm': '5', 'NetReward': 242792, 'Pull': 1130...
# 98  {'Arm': '5', 'NetReward': 242818, 'Pull': 1130...
# 99  {'Arm': '5', 'NetReward': 242841, 'Pull': 1130...
#
#                                                 arm_6  \
# 0   {'Arm': '6', 'NetReward': 242865, 'Pull': 1130...
# 1   {'Arm': '6', 'NetReward': 242885, 'Pull': 1130...
# 2   {'Arm': '6', 'NetReward': 242894, 'Pull': 1130...
# 3   {'Arm': '6', 'NetReward': 242913, 'Pull': 1130...
# 4   {'Arm': '6', 'NetReward': 242932, 'Pull': 1130...
# ..                                                ...
# 95  {'Arm': '6', 'NetReward': 244267, 'Pull': 1139...
# 96  {'Arm': '6', 'NetReward': 244283, 'Pull': 1139...
# 97  {'Arm': '6', 'NetReward': 244299, 'Pull': 1140...
# 98  {'Arm': '6', 'NetReward': 244319, 'Pull': 1140...
# 99  {'Arm': '6', 'NetReward': 244336, 'Pull': 1140...
#
#                                                 arm_7  \
# 0   {'Arm': '7', 'NetReward': 244351, 'Pull': 1140...
# 1   {'Arm': '7', 'NetReward': 244369, 'Pull': 1140...
# 2   {'Arm': '7', 'NetReward': 244390, 'Pull': 1140...
# 3   {'Arm': '7', 'NetReward': 244409, 'Pull': 1140...
# 4   {'Arm': '7', 'NetReward': 244423, 'Pull': 1140...
# ..                                                ...
# 95  {'Arm': '7', 'NetReward': 245942, 'Pull': 1149...
# 96  {'Arm': '7', 'NetReward': 245958, 'Pull': 1149...
# 97  {'Arm': '7', 'NetReward': 245978, 'Pull': 1150...
# 98  {'Arm': '7', 'NetReward': 245995, 'Pull': 1150...
# 99  {'Arm': '7', 'NetReward': 246012, 'Pull': 1150...
#
#                                                 arm_8  \
# 0   {'Arm': '8', 'NetReward': 246025, 'Pull': 1150...
# 1   {'Arm': '8', 'NetReward': 246039, 'Pull': 1150...
# 2   {'Arm': '8', 'NetReward': 246049, 'Pull': 1150...
# 3   {'Arm': '8', 'NetReward': 246059, 'Pull': 1150...
# 4   {'Arm': '8', 'NetReward': 246071, 'Pull': 1150...
# ..                                                ...
# 95  {'Arm': '8', 'NetReward': 247199, 'Pull': 1159...
# 96  {'Arm': '8', 'NetReward': 247210, 'Pull': 1159...
# 97  {'Arm': '8', 'NetReward': 247214, 'Pull': 1160...
# 98  {'Arm': '8', 'NetReward': 247223, 'Pull': 1160...
# 99  {'Arm': '8', 'NetReward': 247232, 'Pull': 1160...
#
#                                                 arm_9  ...  \
# 0   {'Arm': '9', 'NetReward': 247250, 'Pull': 1160...  ...
# 1   {'Arm': '9', 'NetReward': 247265, 'Pull': 1160...  ...
# 2   {'Arm': '9', 'NetReward': 247284, 'Pull': 1160...  ...
# 3   {'Arm': '9', 'NetReward': 247302, 'Pull': 1160...  ...
# 4   {'Arm': '9', 'NetReward': 247324, 'Pull': 1160...  ...
# ..                                                ...  ...
# 95  {'Arm': '9', 'NetReward': 249072, 'Pull': 1169...  ...
# 96  {'Arm': '9', 'NetReward': 249090, 'Pull': 1169...  ...
# 97  {'Arm': '9', 'NetReward': 249108, 'Pull': 1170...  ...
# 98  {'Arm': '9', 'NetReward': 249126, 'Pull': 1170...  ...
# 99  {'Arm': '9', 'NetReward': 249141, 'Pull': 1170...  ...
#
#                                                arm_14  \
# 0   {'Arm': '14', 'NetReward': 254985, 'Pull': 121...
# 1   {'Arm': '14', 'NetReward': 254993, 'Pull': 121...
# 2   {'Arm': '14', 'NetReward': 255002, 'Pull': 121...
# 3   {'Arm': '14', 'NetReward': 255012, 'Pull': 121...
# 4   {'Arm': '14', 'NetReward': 255019, 'Pull': 121...
# ..                                                ...
# 95  {'Arm': '14', 'NetReward': 255764, 'Pull': 121...
# 96  {'Arm': '14', 'NetReward': 255774, 'Pull': 121...
# 97  {'Arm': '14', 'NetReward': 255786, 'Pull': 122...
# 98  {'Arm': '14', 'NetReward': 255796, 'Pull': 122...
# 99  {'Arm': '14', 'NetReward': 255807, 'Pull': 122...
#
#                                                arm_15  \
# 0   {'Arm': '15', 'NetReward': 255832, 'Pull': 122...
# 1   {'Arm': '15', 'NetReward': 255859, 'Pull': 122...
# 2   {'Arm': '15', 'NetReward': 255885, 'Pull': 122...
# 3   {'Arm': '15', 'NetReward': 255910, 'Pull': 122...
# 4   {'Arm': '15', 'NetReward': 255933, 'Pull': 122...
# ..                                                ...
# 95  {'Arm': '15', 'NetReward': 258056, 'Pull': 122...
# 96  {'Arm': '15', 'NetReward': 258077, 'Pull': 122...
# 97  {'Arm': '15', 'NetReward': 258100, 'Pull': 123...
# 98  {'Arm': '15', 'NetReward': 258125, 'Pull': 123...
# 99  {'Arm': '15', 'NetReward': 258145, 'Pull': 123...
#
#                                                arm_16  \
# 0   {'Arm': '16', 'NetReward': 258157, 'Pull': 123...
# 1   {'Arm': '16', 'NetReward': 258168, 'Pull': 123...
# 2   {'Arm': '16', 'NetReward': 258188, 'Pull': 123...
# 3   {'Arm': '16', 'NetReward': 258200, 'Pull': 123...
# 4   {'Arm': '16', 'NetReward': 258212, 'Pull': 123...
# ..                                                ...
# 95  {'Arm': '16', 'NetReward': 259387, 'Pull': 123...
# 96  {'Arm': '16', 'NetReward': 259406, 'Pull': 123...
# 97  {'Arm': '16', 'NetReward': 259423, 'Pull': 124...
# 98  {'Arm': '16', 'NetReward': 259434, 'Pull': 124...
# 99  {'Arm': '16', 'NetReward': 259446, 'Pull': 124...
#
#                                                arm_17  \
# 0   {'Arm': '17', 'NetReward': 259459, 'Pull': 124...
# 1   {'Arm': '17', 'NetReward': 259471, 'Pull': 124...
# 2   {'Arm': '17', 'NetReward': 259487, 'Pull': 124...
# 3   {'Arm': '17', 'NetReward': 259496, 'Pull': 124...
# 4   {'Arm': '17', 'NetReward': 259512, 'Pull': 124...
# ..                                                ...
# 95  {'Arm': '17', 'NetReward': 260767, 'Pull': 124...
# 96  {'Arm': '17', 'NetReward': 260780, 'Pull': 124...
# 97  {'Arm': '17', 'NetReward': 260797, 'Pull': 125...
# 98  {'Arm': '17', 'NetReward': 260812, 'Pull': 125...
# 99  {'Arm': '17', 'NetReward': 260826, 'Pull': 125...
#
#                                                arm_18  \
# 0   {'Arm': '18', 'NetReward': 260839, 'Pull': 125...
# 1   {'Arm': '18', 'NetReward': 260850, 'Pull': 125...
# 2   {'Arm': '18', 'NetReward': 260866, 'Pull': 125...
# 3   {'Arm': '18', 'NetReward': 260877, 'Pull': 125...
# 4   {'Arm': '18', 'NetReward': 260889, 'Pull': 125...
# ..                                                ...
# 95  {'Arm': '18', 'NetReward': 262105, 'Pull': 125...
# 96  {'Arm': '18', 'NetReward': 262117, 'Pull': 125...
# 97  {'Arm': '18', 'NetReward': 262125, 'Pull': 126...
# 98  {'Arm': '18', 'NetReward': 262140, 'Pull': 126...
# 99  {'Arm': '18', 'NetReward': 262145, 'Pull': 126...
#
#                                                arm_19  \
# 0   {'Arm': '19', 'NetReward': 262152, 'Pull': 126...
# 1   {'Arm': '19', 'NetReward': 262158, 'Pull': 126...
# 2   {'Arm': '19', 'NetReward': 262168, 'Pull': 126...
# 3   {'Arm': '19', 'NetReward': 262173, 'Pull': 126...
# 4   {'Arm': '19', 'NetReward': 262182, 'Pull': 126...
# ..                                                ...
# 95  {'Arm': '19', 'NetReward': 262885, 'Pull': 126...
# 96  {'Arm': '19', 'NetReward': 262891, 'Pull': 126...
# 97  {'Arm': '19', 'NetReward': 262902, 'Pull': 127...
# 98  {'Arm': '19', 'NetReward': 262912, 'Pull': 127...
# 99  {'Arm': '19', 'NetReward': 262918, 'Pull': 127...
#
#                                                arm_20  \
# 0   {'Arm': '20', 'NetReward': 262940, 'Pull': 127...
# 1   {'Arm': '20', 'NetReward': 262960, 'Pull': 127...
# 2   {'Arm': '20', 'NetReward': 262980, 'Pull': 127...
# 3   {'Arm': '20', 'NetReward': 263001, 'Pull': 127...
# 4   {'Arm': '20', 'NetReward': 263017, 'Pull': 127...
# ..                                                ...
# 95  {'Arm': '20', 'NetReward': 264830, 'Pull': 127...
# 96  {'Arm': '20', 'NetReward': 264845, 'Pull': 127...
# 97  {'Arm': '20', 'NetReward': 264866, 'Pull': 128...
# 98  {'Arm': '20', 'NetReward': 264885, 'Pull': 128...
# 99  {'Arm': '20', 'NetReward': 264918, 'Pull': 128...
#
#                                                arm_21  \
# 0   {'Arm': '21', 'NetReward': 264939, 'Pull': 128...
# 1   {'Arm': '21', 'NetReward': 264972, 'Pull': 128...
# 2   {'Arm': '21', 'NetReward': 264990, 'Pull': 128...
# 3   {'Arm': '21', 'NetReward': 265020, 'Pull': 128...
# 4   {'Arm': '21', 'NetReward': 265038, 'Pull': 128...
# ..                                                ...
# 95  {'Arm': '21', 'NetReward': 267310, 'Pull': 128...
# 96  {'Arm': '21', 'NetReward': 267336, 'Pull': 128...
# 97  {'Arm': '21', 'NetReward': 267358, 'Pull': 129...
# 98  {'Arm': '21', 'NetReward': 267380, 'Pull': 129...
# 99  {'Arm': '21', 'NetReward': 267406, 'Pull': 129...
#
#                                                arm_22  \
# 0   {'Arm': '22', 'NetReward': 267413, 'Pull': 129...
# 1   {'Arm': '22', 'NetReward': 267427, 'Pull': 129...
# 2   {'Arm': '22', 'NetReward': 267434, 'Pull': 129...
# 3   {'Arm': '22', 'NetReward': 267438, 'Pull': 129...
# 4   {'Arm': '22', 'NetReward': 267445, 'Pull': 129...
# ..                                                ...
# 95  {'Arm': '22', 'NetReward': 268123, 'Pull': 129...
# 96  {'Arm': '22', 'NetReward': 268130, 'Pull': 129...
# 97  {'Arm': '22', 'NetReward': 268137, 'Pull': 130...
# 98  {'Arm': '22', 'NetReward': 268145, 'Pull': 130...
# 99  {'Arm': '22', 'NetReward': 268153, 'Pull': 130...
#
#                                                arm_23
# 0   {'Arm': '23', 'NetReward': 268164, 'Pull': 130...
# 1   {'Arm': '23', 'NetReward': 268178, 'Pull': 130...
# 2   {'Arm': '23', 'NetReward': 268192, 'Pull': 130...
# 3   {'Arm': '23', 'NetReward': 268211, 'Pull': 130...
# 4   {'Arm': '23', 'NetReward': 268232, 'Pull': 130...
# ..                                                ...
# 95  {'Arm': '23', 'NetReward': 269533, 'Pull': 130...
# 96  {'Arm': '23', 'NetReward': 269545, 'Pull': 130...
# 97  {'Arm': '23', 'NetReward': 269552, 'Pull': 131...
# 98  {'Arm': '23', 'NetReward': 269568, 'Pull': 131...
# 99  {'Arm': '23', 'NetReward': 269576, 'Pull': 131...
#
# [100 rows x 24 columns]

# %%
df_reward = pd.DataFrame()
for col in df.columns:
    # Extract 'Reward' values from each column and append them to the new DataFrame
    df_reward[col] = df[col].apply(lambda x: x['Reward'])

# Display the new DataFrame with 'Reward' values
df_reward.to_csv('arm_reward_distribution.csv')
print(df_reward)
# Out:
#     arm_0  arm_1  arm_2  arm_3  arm_4  arm_5  arm_6  arm_7  arm_8  arm_9  ...  \
# 0       5     17     29     15     25     17     24     15     13     18  ...
# 1      11     13     22     18     19     28     20     18     14     15  ...
# 2       3     16     21     24     20     27      9     21     10     19  ...
# 3       6     19     19     12     13     21     19     19     10     18  ...
# 4       8     20     17     15     16     26     19     14     12     22  ...
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 95      5     22     13     15     17     20      9     12     13     19  ...
# 96      8     11     31     23     15     20     16     16     11     18  ...
# 97      5     19     24     24     27     20     16     20      4     18  ...
# 98      8     19     19     11     18     26     20     17      9     18  ...
# 99      4     17     26     14     22     23     17     17      9     15  ...
#
#     arm_14  arm_15  arm_16  arm_17  arm_18  arm_19  arm_20  arm_21  arm_22  \
# 0       11      25      12      13      13       7      22      21       7
# 1        8      27      11      12      11       6      20      33      14
# 2        9      26      20      16      16      10      20      18       7
# 3       10      25      12       9      11       5      21      30       4
# 4        7      23      12      16      12       9      16      18       7
# ..     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 95      12      27      11      11      11       8      21      25       8
# 96      10      21      19      13      12       6      15      26       7
# 97      12      23      17      17       8      11      21      22       7
# 98      10      25      11      15      15      10      19      22       8
# 99      11      20      12      14       5       6      33      26       8
#
#     arm_23
# 0       11
# 1       14
# 2       14
# 3       19
# 4       21
# ..     ...
# 95      10
# 96      12
# 97       7
# 98      16
# 99       8
#
# [100 rows x 24 columns]

# %%
# Create a 4x6 subplot grid
fig, axes = plt.subplots(4, 6, figsize=(18, 12))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate through each column in the DataFrame
for i, column in enumerate(df_reward.columns):
    # Plot a histogram for the current column in the corresponding subplot
    axes[i].hist(df_reward[column], bins=10, color='skyblue', edgecolor='black')
    axes[i].set_title(column)  # Set the title of each subplot

    # Calculate the mean of the current column
    mean_value = df_reward[column].mean()
    
    # Plot a red dotted line for the mean value
    axes[i].axvline(x=mean_value, color='red', linestyle='--', label=f'Mean: {mean_value:.2f}')
    axes[i].legend()  # Show the legend
    
# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
mean_values = df_reward.mean()

# Convert the mean values to a DataFrame for sorting and printing
mean_df = pd.DataFrame({'Column Name': mean_values.index, 'Mean Value': mean_values.values})

# Sort the DataFrame by 'Mean Value' in descending order
mean_df = mean_df.sort_values(by='Mean Value', ascending=False)

# Display the sorted mean values along with the column names
print(mean_df)
# Out:
#    Column Name  Mean Value
# 21      arm_21       24.88
# 15      arm_15       23.38
# 13      arm_13       22.84
# 2        arm_2       21.98
# 5        arm_5       21.46
# 20      arm_20       20.00
# 10      arm_10       19.57
# 9        arm_9       19.09
# 3        arm_3       18.52
# 4        arm_4       18.43
# 7        arm_7       16.76
# 1        arm_1       16.35
# 6        arm_6       14.95
# 23      arm_23       14.23
# 17      arm_17       13.80
# 18      arm_18       13.19
# 16      arm_16       13.01
# 8        arm_8       12.20
# 11      arm_11       10.12
# 14      arm_14        8.33
# 19      arm_19        7.73
# 22      arm_22        7.47
# 0        arm_0        7.10
# 12      arm_12        5.80

# %%
# Perform Shapiro-Wilk test for normality on each column
for column in df_reward.columns:
    # Perform the Shapiro-Wilk test on the current column
    stat, p_value = shapiro(df_reward[column])
    
    # Print the test statistic and p-value for each column
    print(f"Column: {column}, Test Statistic: {stat:.4f}, P-value: {p_value:.4f}")
# Out:
# Column: arm_0, Test Statistic: 0.9654, P-value: 0.0099
# Column: arm_1, Test Statistic: 0.9734, P-value: 0.0402
# Column: arm_2, Test Statistic: 0.9841, P-value: 0.2711
# Column: arm_3, Test Statistic: 0.9830, P-value: 0.2278
# Column: arm_4, Test Statistic: 0.9746, P-value: 0.0498
# Column: arm_5, Test Statistic: 0.9889, P-value: 0.5778
# Column: arm_6, Test Statistic: 0.9835, P-value: 0.2448
# Column: arm_7, Test Statistic: 0.9794, P-value: 0.1194
# Column: arm_8, Test Statistic: 0.9871, P-value: 0.4456
# Column: arm_9, Test Statistic: 0.9821, P-value: 0.1915
# Column: arm_10, Test Statistic: 0.9737, P-value: 0.0429
# Column: arm_11, Test Statistic: 0.9754, P-value: 0.0585
# Column: arm_12, Test Statistic: 0.9732, P-value: 0.0391
# Column: arm_13, Test Statistic: 0.9880, P-value: 0.5087
# Column: arm_14, Test Statistic: 0.9739, P-value: 0.0441
# Column: arm_15, Test Statistic: 0.9735, P-value: 0.0411
# Column: arm_16, Test Statistic: 0.9791, P-value: 0.1135
# Column: arm_17, Test Statistic: 0.9760, P-value: 0.0642
# Column: arm_18, Test Statistic: 0.9780, P-value: 0.0929
# Column: arm_19, Test Statistic: 0.9741, P-value: 0.0460
# Column: arm_20, Test Statistic: 0.9731, P-value: 0.0383
# Column: arm_21, Test Statistic: 0.9912, P-value: 0.7582
# Column: arm_22, Test Statistic: 0.9736, P-value: 0.0421
# Column: arm_23, Test Statistic: 0.9635, P-value: 0.0072

# %%
from scipy.stats import shapiro

# Assuming 'df' is your DataFrame with 24 columns

# Initialize lists to store results
significant_results = []
non_significant_results = []

# Perform Shapiro-Wilk test for normality on each column
for column in df_reward.columns:
    # Perform the Shapiro-Wilk test on the current column
    stat, p_value = shapiro(df_reward[column])
    
    # Check if the p-value is less than 0.05
    if p_value < 0.05:
        # Store significant results together
        significant_results.append(f"Column: {column}, Test Statistic: {stat:.4f}, P-value: {p_value:.4f}")
    else:
        # Store non-significant results together
        non_significant_results.append(f"Column: {column}, Test Statistic: {stat:.4f}, P-value: {p_value:.4f}")

# Print significant results
print(f'There are {len(significant_results)} arms that are not normally distributed') 
print("\n".join(significant_results))
print()  # Empty line between significant and non-significant results

# Print non-significant results
print(f'There are {len(non_significant_results)} arms that are normally distributed') 
print("\n".join(non_significant_results))
# Out:
# There are 11 arms that are not normally distributed
# Column: arm_0, Test Statistic: 0.9654, P-value: 0.0099
# Column: arm_1, Test Statistic: 0.9734, P-value: 0.0402
# Column: arm_4, Test Statistic: 0.9746, P-value: 0.0498
# Column: arm_10, Test Statistic: 0.9737, P-value: 0.0429
# Column: arm_12, Test Statistic: 0.9732, P-value: 0.0391
# Column: arm_14, Test Statistic: 0.9739, P-value: 0.0441
# Column: arm_15, Test Statistic: 0.9735, P-value: 0.0411
# Column: arm_19, Test Statistic: 0.9741, P-value: 0.0460
# Column: arm_20, Test Statistic: 0.9731, P-value: 0.0383
# Column: arm_22, Test Statistic: 0.9736, P-value: 0.0421
# Column: arm_23, Test Statistic: 0.9635, P-value: 0.0072
#
# There are 13 arms that are normally distributed
# Column: arm_2, Test Statistic: 0.9841, P-value: 0.2711
# Column: arm_3, Test Statistic: 0.9830, P-value: 0.2278
# Column: arm_5, Test Statistic: 0.9889, P-value: 0.5778
# Column: arm_6, Test Statistic: 0.9835, P-value: 0.2448
# Column: arm_7, Test Statistic: 0.9794, P-value: 0.1194
# Column: arm_8, Test Statistic: 0.9871, P-value: 0.4456
# Column: arm_9, Test Statistic: 0.9821, P-value: 0.1915
# Column: arm_11, Test Statistic: 0.9754, P-value: 0.0585
# Column: arm_13, Test Statistic: 0.9880, P-value: 0.5087
# Column: arm_16, Test Statistic: 0.9791, P-value: 0.1135
# Column: arm_17, Test Statistic: 0.9760, P-value: 0.0642
# Column: arm_18, Test Statistic: 0.9780, P-value: 0.0929
# Column: arm_21, Test Statistic: 0.9912, P-value: 0.7582
